# %%
import mysql.connector
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
Airline = pd.read_csv('C:/Users/Justin/Documents/Grad Courses/DNSC 6211 - Programming for Analytics\Week 10/Assignment 9/airlines.csv')
Airport = pd.read_csv('C:/Users/Justin/Documents/Grad Courses/DNSC 6211 - Programming for Analytics/Week 10/Assignment 9/airports.csv')
Flight = pd.read_csv('C:/Users/Justin/Documents/Grad Courses/DNSC 6211 - Programming for Analytics/Week 10/Assignment 9/flights.csv')
Plane = pd.read_csv('C:/Users/Justin/Documents/Grad Courses/DNSC 6211 - Programming for Analytics/Week 10/Assignment 9/planes.csv')
Weather = pd.read_csv('C:/Users/Justin/Documents/Grad Courses/DNSC 6211 - Programming for Analytics/Week 10/Assignment 9/weather.csv')

#read the original csv files into pandas/jupyter

# %%
#Part A - i

# %%
#ensure the files properly loaded into pandas

Airline.head()
# Out:
#    Unnamed: 0 carrier                    name
# 0           1      9E       Endeavor Air Inc.
# 1           2      AA  American Airlines Inc.
# 2           3      AS    Alaska Airlines Inc.
# 3           4      B6         JetBlue Airways
# 4           5      DL    Delta Air Lines Inc.

# %%
#the following row counts provide information about potentially missing data

Airline.count()
# Out:
# Unnamed: 0    16
# carrier       16
# name          16
# dtype: int64

# %%
#the shape function provides a true row count for the dataset for each csv file
        
Airline.shape[0]
# Out:
# 16

# %%
Airport.count()
# Out:
# Unnamed: 0    1458
# faa           1458
# name          1458
# lat           1458
# lon           1458
# alt           1458
# tz            1458
# dst           1458
# tzone         1458
# dtype: int64

# %%
Airport.shape[0]
# Out:
# 1458

# %%
Flight.count()
# Out:
# Column1           336776
# year              336776
# month             336776
# day               336776
# dep_time          328521
# sched_dep_time    336776
# dep_delay         328521
# arr_time          328063
# sched_arr_time    336776
# arr_delay         327346
# carrier           336776
# flight            336776
# tailnum           334264
# origin            336776
# dest              336776
# air_time          327346
# distance          336776
# hour              336776
# minute            336776
# time_hour         336776
# dtype: int64

# %%
Flight.shape[0]
# Out:
# 336776

# %%
Plane.count()
# Out:
# Unnamed: 0      3322
# tailnum         3322
# year            3252
# type            3322
# manufacturer    3322
# model           3322
# engines         3322
# seats           3322
# speed             23
# engine          3322
# dtype: int64

# %%
Plane.shape[0]
# Out:
# 3322

# %%
Weather.count()
# Out:
# Column1       26130
# origin        26130
# year          26130
# month         26130
# day           26130
# hour          26130
# temp          26129
# dewp          26129
# humid         26129
# wind_dir      25712
# wind_speed    26127
# wind_gust     26127
# precip        26130
# pressure      23400
# visib         26130
# time_hour     26130
# dtype: int64

# %%
Weather.shape[0]
# Out:
# 26130

# %%
#the count and shape functions show that the Airline and Airport csv files do not have any missing data, so these are good to use as presented.
#the Plane dataset has only one column showing missing values and this column is not required to complete the analysis, so I will remove this column.
#the Flight and Weather dataset shows several instances of missing values, so these two datasets require further cleaning.

# %%
#clean the Plane csv by removing the Speed variable because it contains an excessive amount of NaNs (missing values)
#the csv to use for the Plane data is known as PlaneC

PlaneC = Plane[['tailnum', 'year', 'type', 'manufacturer', 'model', 'engines', 'seats', 'engine']]
print(PlaneC)
# Out:
#      tailnum    year                     type                   manufacturer  \
# 0     N10156  2004.0  Fixed wing multi engine                        EMBRAER
# 1     N102UW  1998.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 2     N103US  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 3     N104UW  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 4     N10575  2002.0  Fixed wing multi engine                        EMBRAER
# 5     N105UW  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 6     N107US  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 7     N108UW  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 8     N109UW  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 9     N110UW  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 10    N11106  2002.0  Fixed wing multi engine                        EMBRAER
# ...

# %%
#for the Weather dataset, I identified multiple columns with missing values. I will find the mean of each of these columns and replace the NaNs with the mean.

a = Weather["temp"].mean()
b = Weather["dewp"].mean()
c = Weather["humid"].mean()
d = Weather["wind_dir"].mean()
e = Weather["wind_speed"].mean()
f = Weather["wind_gust"].mean()
g = Weather["pressure"].mean()
print(a, b, c, d, e, f, g)
# Out:
# 55.203514868537034 41.38539936469043 62.34732174977937 198.06666148102053 10.39586823975324 11.963357253109523 1017.8951752136738

# %%
#I create new columns that fill the NaNs with the column mean

WeatherC1 = Weather["temp"].fillna(a)
print(WeatherC1)
# Out:
# 0        37.04
# 1        37.04
# 2        37.94
# 3        37.94
# 4        37.94
# 5        39.02
# 6        39.02
# 7        39.02
# 8        39.92
# 9        39.02
# 10       37.94
# 11       39.02
# 12       39.92
# 13       39.92
# 14       41.00
# 15       41.00
# 16       39.20
# 17       39.20
# 18       39.02
# 19       37.94
# 20       37.04
# 21       35.96
# 22       33.98
# 23       33.08
# 24       32.00
# 25       30.02
# 26       28.94
# 27       28.04
# 28       26.96
# 29       26.06
#          ...
# 26100    42.80
# 26101    39.20
# 26102    41.00
# 26103    41.00
# 26104    41.00
# 26105    42.08
# 26106    42.80
# 26107    41.00
# 26108    42.80
# 26109    42.98
# 26110    42.98
# 26111    42.08
# 26112    42.08
# 26113    41.00
# 26114    42.98
# 26115    41.00
# 26116    42.98
# 26117    42.98
# 26118    44.06
# 26119    44.06
# 26120    44.06
# 26121    42.80
# 26122    41.00
# 26123    37.94
# 26124    37.04
# 26125    35.96
# 26126    33.98
# ...

# %%
#I can check the rows with previously missing values to ensure that the missing values were replaced by the mean

WeatherC1.loc[5596, ]
# Out:
# 55.203514868537034

# %%
tempc3 = WeatherC1
print(tempc3)

#do i need this one?? Need to see if I use tempc3 or weatherc3 later in the code
# Out:
# 0        37.04
# 1        37.04
# 2        37.94
# 3        37.94
# 4        37.94
# 5        39.02
# 6        39.02
# 7        39.02
# 8        39.92
# 9        39.02
# 10       37.94
# 11       39.02
# 12       39.92
# 13       39.92
# 14       41.00
# 15       41.00
# 16       39.20
# 17       39.20
# 18       39.02
# 19       37.94
# 20       37.04
# 21       35.96
# 22       33.98
# 23       33.08
# 24       32.00
# 25       30.02
# 26       28.94
# 27       28.04
# 28       26.96
# 29       26.06
#          ...
# 26100    42.80
# 26101    39.20
# 26102    41.00
# 26103    41.00
# 26104    41.00
# 26105    42.08
# 26106    42.80
# 26107    41.00
# 26108    42.80
# 26109    42.98
# 26110    42.98
# 26111    42.08
# 26112    42.08
# 26113    41.00
# 26114    42.98
# 26115    41.00
# 26116    42.98
# 26117    42.98
# 26118    44.06
# 26119    44.06
# 26120    44.06
# 26121    42.80
# 26122    41.00
# 26123    37.94
# 26124    37.04
# 26125    35.96
# 26126    33.98
# ...

# %%
Weatherc3 = Weather["dewp"].fillna(b)
print(Weatherc3)
# Out:
# 0        21.92
# 1        21.92
# 2        21.92
# 3        23.00
# 4        24.08
# 5        26.06
# 6        26.96
# 7        28.04
# 8        28.04
# 9        28.04
# 10       28.04
# 11       28.04
# 12       28.04
# 13       28.04
# 14       28.04
# 15       26.96
# 16       28.40
# 17       28.40
# 18       24.08
# 19       24.08
# 20       19.94
# 21       19.04
# 22       15.08
# 23       12.92
# 24       15.08
# 25       12.92
# 26       12.02
# 27       10.94
# 28       10.94
# 29       10.94
#          ...
# 26100    37.40
# 26101    37.40
# 26102    39.02
# 26103    37.94
# 26104    39.20
# 26105    39.02
# 26106    37.40
# 26107    37.40
# 26108    37.40
# 26109    37.04
# 26110    35.06
# 26111    33.98
# 26112    33.98
# 26113    33.98
# 26114    33.98
# 26115    33.08
# 26116    33.08
# 26117    33.98
# 26118    35.06
# 26119    33.98
# 26120    33.08
# 26121    33.80
# 26122    28.40
# 26123    23.00
# 26124    21.92
# 26125    19.94
# 26126    17.06
# ...

# %%
Weatherc3.loc[5596, ]
# Out:
# 41.385399364690429

# %%
dewpc3 = Weatherc3
print(dewpc3)

#I guess I am renaming these for some reason
# Out:
# 0        21.92
# 1        21.92
# 2        21.92
# 3        23.00
# 4        24.08
# 5        26.06
# 6        26.96
# 7        28.04
# 8        28.04
# 9        28.04
# 10       28.04
# 11       28.04
# 12       28.04
# 13       28.04
# 14       28.04
# 15       26.96
# 16       28.40
# 17       28.40
# 18       24.08
# 19       24.08
# 20       19.94
# 21       19.04
# 22       15.08
# 23       12.92
# 24       15.08
# 25       12.92
# 26       12.02
# 27       10.94
# 28       10.94
# 29       10.94
#          ...
# 26100    37.40
# 26101    37.40
# 26102    39.02
# 26103    37.94
# 26104    39.20
# 26105    39.02
# 26106    37.40
# 26107    37.40
# 26108    37.40
# 26109    37.04
# 26110    35.06
# 26111    33.98
# 26112    33.98
# 26113    33.98
# 26114    33.98
# 26115    33.08
# 26116    33.08
# 26117    33.98
# 26118    35.06
# 26119    33.98
# 26120    33.08
# 26121    33.80
# 26122    28.40
# 26123    23.00
# 26124    21.92
# 26125    19.94
# 26126    17.06
# ...

# %%
humidc3 = Weather["humid"].fillna(c)
print(humidc3)
# Out:
# 0        53.97
# 1        53.97
# 2        52.09
# 3        54.51
# 4        57.04
# 5        59.37
# 6        61.63
# 7        64.43
# 8        62.21
# 9        64.43
# 10       67.21
# 11       64.43
# 12       62.21
# 13       62.21
# 14       59.65
# 15       57.06
# 16       64.93
# 17       64.93
# 18       54.68
# 19       57.04
# 20       49.62
# 21       49.83
# 22       45.43
# 23       42.84
# 24       49.19
# 25       48.48
# 26       48.69
# 27       48.15
# 28       50.34
# 29       52.25
#          ...
# 26100    81.07
# 26101    93.19
# 26102    92.59
# 26103    88.76
# 26104    93.24
# 26105    88.81
# 26106    81.07
# 26107    86.89
# 26108    81.07
# 26109    79.38
# 26110    73.39
# 26111    72.78
# 26112    72.78
# 26113    75.88
# 26114    70.30
# 26115    73.19
# 26116    67.81
# 26117    70.30
# 26118    70.42
# 26119    67.45
# 26120    65.07
# 26121    70.28
# 26122    60.54
# 26123    54.51
# 26124    53.97
# 26125    51.78
# 26126    49.51
# ...

# %%
humidc3.loc[5596, ]
# Out:
# 62.347321749779368

# %%
wind_dirc3 = Weather["wind_dir"].fillna(d)
print(wind_dirc3)
# Out:
# 0        230.0
# 1        230.0
# 2        230.0
# 3        230.0
# 4        240.0
# 5        270.0
# 6        250.0
# 7        240.0
# 8        250.0
# 9        260.0
# 10       240.0
# 11       240.0
# 12       250.0
# 13       260.0
# 14       260.0
# 15       260.0
# 16       270.0
# 17       330.0
# 18       280.0
# 19       290.0
# 20       300.0
# 21       330.0
# 22       310.0
# 23       320.0
# 24       310.0
# 25       320.0
# 26       320.0
# 27       310.0
# 28       310.0
# 29       330.0
#          ...
# 26100     70.0
# 26101     40.0
# 26102     40.0
# 26103    350.0
# 26104     50.0
# 26105    330.0
# 26106    320.0
# 26107    310.0
# 26108    320.0
# 26109    300.0
# 26110    310.0
# 26111    320.0
# 26112    250.0
# 26113    240.0
# 26114    270.0
# 26115      0.0
# 26116    250.0
# 26117    230.0
# 26118    240.0
# 26119    260.0
# 26120    260.0
# 26121    330.0
# 26122    340.0
# 26123    330.0
# 26124    340.0
# 26125    340.0
# 26126    330.0
# ...

# %%
wind_dirc3.loc[1787:1790, ]
# Out:
# 1787    198.066661
# 1788    198.066661
# 1789    198.066661
# 1790    198.066661
# Name: wind_dir, dtype: float64

# %%
wind_speedc3 = Weather["wind_speed"].fillna(e)
print(wind_speedc3)
# Out:
# 0        10.35702
# 1        13.80936
# 2        12.65858
# 3        13.80936
# 4        14.96014
# 5        10.35702
# 6         8.05546
# 7        11.50780
# 8        12.65858
# 9        12.65858
# 10       11.50780
# 11       14.96014
# 12       10.35702
# 13       14.96014
# 14       13.80936
# 15       14.96014
# 16       16.11092
# 17       14.96014
# 18       13.80936
# 19        9.20624
# 20       13.80936
# 21       11.50780
# 22       12.65858
# 23       10.35702
# 24       14.96014
# 25       18.41248
# 26       18.41248
# 27       16.11092
# 28       14.96014
# 29       12.65858
#            ...
# 26100     9.20624
# 26101    16.11092
# 26102    13.80936
# 26103     8.05546
# 26104    20.71404
# 26105    14.96014
# 26106    17.26170
# 26107    19.56326
# 26108    16.11092
# 26109     9.20624
# 26110    17.26170
# 26111    11.50780
# 26112     9.20624
# 26113     8.05546
# 26114     9.20624
# 26115     0.00000
# 26116    10.35702
# 26117     6.90468
# 26118    11.50780
# ...

# %%
wind_speedc3.loc[13513, ]
# Out:
# 10.39586823975324

# %%
wind_gustc3 = Weather["wind_gust"].fillna(f)
print(wind_gustc3)
# Out:
# 0        11.918651
# 1        15.891535
# 2        14.567241
# 3        15.891535
# 4        17.215830
# 5        11.918651
# 6         9.270062
# 7        13.242946
# 8        14.567241
# 9        14.567241
# 10       13.242946
# 11       17.215830
# 12       11.918651
# 13       17.215830
# 14       15.891535
# 15       17.215830
# 16       18.540125
# 17       17.215830
# 18       15.891535
# 19       10.594357
# 20       15.891535
# 21       13.242946
# 22       14.567241
# 23       11.918651
# 24       17.215830
# 25       21.188714
# 26       21.188714
# 27       18.540125
# 28       17.215830
# 29       14.567241
#            ...
# 26100    10.594357
# 26101    18.540125
# 26102    15.891535
# 26103     9.270062
# 26104    23.837303
# 26105    17.215830
# 26106    19.864419
# 26107    22.513008
# 26108    18.540125
# 26109    10.594357
# 26110    19.864419
# 26111    13.242946
# 26112    10.594357
# 26113     9.270062
# 26114    10.594357
# 26115     0.000000
# ...

# %%
wind_gustc3.loc[2057, ]
# Out:
# 11.963357253109523

# %%
pressurec3 = Weather["pressure"].fillna(e)
print(pressurec3)
# Out:
# 0        1013.900000
# 1        1013.000000
# 2        1012.600000
# 3        1012.700000
# 4        1012.800000
# 5        1012.000000
# 6        1012.300000
# 7        1012.500000
# 8        1012.200000
# 9        1011.900000
# 10       1012.400000
# 11       1012.200000
# 12       1012.200000
# 13       1012.700000
# 14       1012.400000
# 15       1011.400000
# 16         10.395868
# 17         10.395868
# 18       1010.800000
# 19       1011.900000
# 20       1012.100000
# 21       1013.200000
# 22       1014.100000
# 23       1014.400000
# 24       1015.200000
# 25       1016.000000
# 26       1016.500000
# 27       1016.400000
# 28       1016.300000
# 29       1016.300000
#             ...
# 26100      10.395868
# 26101      10.395868
# 26102     999.900000
# 26103     998.700000
# 26104      10.395868
# 26105     997.200000
# 26106      10.395868
# 26107      10.395868
# 26108      10.395868
# 26109    1003.800000
# 26110    1005.100000
# 26111    1005.900000
# ...

# %%
pressurec3.loc[1300:1310, ]
# Out:
# 1300      10.395868
# 1301      10.395868
# 1302    1007.800000
# 1303      10.395868
# 1304      10.395868
# 1305    1008.500000
# 1306      10.395868
# 1307      10.395868
# 1308      10.395868
# 1309    1007.600000
# 1310    1007.500000
# Name: pressure, dtype: float64

# %%
#Now that I have modified columns for the missing data, I can remove the columns that have missing data in the original dataframe

WeatherN2 = Weather.filter(['Unnamed: 0', 'origin', 'year', 'month', 'day', 'hour', 'precip', 'visib', 'time_hour'], axis=1)
print(WeatherN2)
# Out:
#       origin  year  month  day  hour  precip  visib         time_hour
# 0        EWR  2013      1    1     0    0.00  10.00  12/31/2012 19:00
# 1        EWR  2013      1    1     1    0.00  10.00  12/31/2012 20:00
# 2        EWR  2013      1    1     2    0.00  10.00  12/31/2012 21:00
# 3        EWR  2013      1    1     3    0.00  10.00  12/31/2012 22:00
# 4        EWR  2013      1    1     4    0.00  10.00  12/31/2012 23:00
# 5        EWR  2013      1    1     6    0.00  10.00     1/1/2013 1:00
# 6        EWR  2013      1    1     7    0.00  10.00     1/1/2013 2:00
# 7        EWR  2013      1    1     8    0.00  10.00     1/1/2013 3:00
# 8        EWR  2013      1    1     9    0.00  10.00     1/1/2013 4:00
# 9        EWR  2013      1    1    10    0.00  10.00     1/1/2013 5:00
# 10       EWR  2013      1    1    11    0.00  10.00     1/1/2013 6:00
# 11       EWR  2013      1    1    12    0.00  10.00     1/1/2013 7:00
# ...

# %%
#Now I need to input the cleaned data back into the dataframe
#I start with just inputting one new column

WeatherN3 = WeatherN2.assign(temp=tempc3.values)
print(WeatherN3)
# Out:
#       origin  year  month  day  hour  precip  visib         time_hour   temp
# 0        EWR  2013      1    1     0    0.00  10.00  12/31/2012 19:00  37.04
# 1        EWR  2013      1    1     1    0.00  10.00  12/31/2012 20:00  37.04
# 2        EWR  2013      1    1     2    0.00  10.00  12/31/2012 21:00  37.94
# 3        EWR  2013      1    1     3    0.00  10.00  12/31/2012 22:00  37.94
# 4        EWR  2013      1    1     4    0.00  10.00  12/31/2012 23:00  37.94
# 5        EWR  2013      1    1     6    0.00  10.00     1/1/2013 1:00  39.02
# 6        EWR  2013      1    1     7    0.00  10.00     1/1/2013 2:00  39.02
# 7        EWR  2013      1    1     8    0.00  10.00     1/1/2013 3:00  39.02
# 8        EWR  2013      1    1     9    0.00  10.00     1/1/2013 4:00  39.92
# 9        EWR  2013      1    1    10    0.00  10.00     1/1/2013 5:00  39.02
# 10       EWR  2013      1    1    11    0.00  10.00     1/1/2013 6:00  37.94
# ...

# %%
#Now that I got the function to work for one column, I use the assign command to input all of the new columns

WeatherN4 = WeatherN3.assign(dewp=dewpc3.values, humid=humidc3.values, wind_dir=wind_dirc3.values, wind_speed=wind_speedc3.values, wind_gust=wind_gustc3.values, pressure=pressurec3.values)
print(WeatherN4)
# Out:
#       origin  year  month  day  hour  precip  visib         time_hour   temp  \
# 0        EWR  2013      1    1     0    0.00  10.00  12/31/2012 19:00  37.04
# 1        EWR  2013      1    1     1    0.00  10.00  12/31/2012 20:00  37.04
# 2        EWR  2013      1    1     2    0.00  10.00  12/31/2012 21:00  37.94
# 3        EWR  2013      1    1     3    0.00  10.00  12/31/2012 22:00  37.94
# 4        EWR  2013      1    1     4    0.00  10.00  12/31/2012 23:00  37.94
# 5        EWR  2013      1    1     6    0.00  10.00     1/1/2013 1:00  39.02
# 6        EWR  2013      1    1     7    0.00  10.00     1/1/2013 2:00  39.02
# 7        EWR  2013      1    1     8    0.00  10.00     1/1/2013 3:00  39.02
# 8        EWR  2013      1    1     9    0.00  10.00     1/1/2013 4:00  39.92
# 9        EWR  2013      1    1    10    0.00  10.00     1/1/2013 5:00  39.02
# 10       EWR  2013      1    1    11    0.00  10.00     1/1/2013 6:00  37.94
# ...

# %%
#I want the cleaned dataframe to be called WeatherC

WeatherC = WeatherN4
print(WeatherC)
# Out:
#       origin  year  month  day  hour  precip  visib         time_hour   temp  \
# 0        EWR  2013      1    1     0    0.00  10.00  12/31/2012 19:00  37.04
# 1        EWR  2013      1    1     1    0.00  10.00  12/31/2012 20:00  37.04
# 2        EWR  2013      1    1     2    0.00  10.00  12/31/2012 21:00  37.94
# 3        EWR  2013      1    1     3    0.00  10.00  12/31/2012 22:00  37.94
# 4        EWR  2013      1    1     4    0.00  10.00  12/31/2012 23:00  37.94
# 5        EWR  2013      1    1     6    0.00  10.00     1/1/2013 1:00  39.02
# 6        EWR  2013      1    1     7    0.00  10.00     1/1/2013 2:00  39.02
# 7        EWR  2013      1    1     8    0.00  10.00     1/1/2013 3:00  39.02
# 8        EWR  2013      1    1     9    0.00  10.00     1/1/2013 4:00  39.92
# 9        EWR  2013      1    1    10    0.00  10.00     1/1/2013 5:00  39.02
# 10       EWR  2013      1    1    11    0.00  10.00     1/1/2013 6:00  37.94
# ...

# %%
#I also need to clean the Flights dataset through the same process

g = Flight["dep_time"].mean()
h = Flight["dep_delay"].mean()
i = Flight["arr_time"].mean()
j = Flight["arr_delay"].mean()
k = Flight["air_time"].mean()
print(g, h, i, j, k)
# Out:
# 1349.1099473093045 12.639070257304708 1502.0549985825894 6.89537675731489 150.68646019807787

# %%
l = Flight["dep_time"].fillna(g)
print(l)
# Out:
# 0          517.000000
# 1          533.000000
# 2          542.000000
# 3          544.000000
# 4          554.000000
# 5          554.000000
# 6          555.000000
# 7          557.000000
# 8          557.000000
# 9          558.000000
# 10         558.000000
# 11         558.000000
# 12         558.000000
# 13         558.000000
# 14         559.000000
# 15         559.000000
# 16         559.000000
# 17         600.000000
# 18         600.000000
# 19         601.000000
# 20         602.000000
# 21         602.000000
# 22         606.000000
# 23         606.000000
# 24         607.000000
# 25         608.000000
# 26         611.000000
# 27         613.000000
# 28         615.000000
# 29         615.000000
#              ...
# 336746    2123.000000
# 336747    2127.000000
# 336748    2128.000000
# 336749    2129.000000
# 336750    2131.000000
# 336751    2140.000000
# 336752    2142.000000
# 336753    2145.000000
# 336754    2147.000000
# 336755    2149.000000
# ...

# %%
l.loc[9751:9762, ]
# Out:
# 9751    1349.109947
# 9752    1349.109947
# 9753    1349.109947
# 9754    1349.109947
# 9755    1349.109947
# 9756    1349.109947
# 9757    1349.109947
# 9758    1349.109947
# 9759    1349.109947
# 9760    1349.109947
# 9761    1349.109947
# 9762      30.000000
# Name: dep_time, dtype: float64

# %%
m = Flight["dep_delay"].fillna(h)
print(m)
# Out:
# 0           2.00000
# 1           4.00000
# 2           2.00000
# 3          -1.00000
# 4          -6.00000
# 5          -4.00000
# 6          -5.00000
# 7          -3.00000
# 8          -3.00000
# 9          -2.00000
# 10         -2.00000
# 11         -2.00000
# 12         -2.00000
# 13         -2.00000
# 14         -1.00000
# 15          0.00000
# 16         -1.00000
# 17          0.00000
# 18          0.00000
# 19          1.00000
# 20         -8.00000
# 21         -3.00000
# 22         -4.00000
# 23         -4.00000
# 24          0.00000
# 25          8.00000
# 26         11.00000
# 27          3.00000
# 28          0.00000
# 29          0.00000
#             ...
# 336746     -2.00000
# 336747     -2.00000
# 336748     -2.00000
# 336749     30.00000
# 336750     -9.00000
# 336751      0.00000
# 336752     13.00000
# 336753      0.00000
# 336754     10.00000
# 336755     -7.00000
# 336756     -9.00000
# 336757    194.00000
# 336758     -2.00000
# 336759     27.00000
# ...

# %%
m.loc[11264:11280, ]
# Out:
# 11264    12.63907
# 11265    12.63907
# 11266    12.63907
# 11267    12.63907
# 11268    12.63907
# 11269    12.63907
# 11270    12.63907
# 11271    12.63907
# 11272    12.63907
# 11273    12.63907
# 11274    12.63907
# 11275    12.63907
# 11276    12.63907
# 11277    12.63907
# 11278    12.63907
# 11279    12.63907
# 11280    -7.00000
# Name: dep_delay, dtype: float64

# %%
n = Flight["arr_time"].fillna(i)
print(n)
# Out:
# 0          830.000000
# 1          850.000000
# 2          923.000000
# 3         1004.000000
# 4          812.000000
# 5          740.000000
# 6          913.000000
# 7          709.000000
# 8          838.000000
# 9          753.000000
# 10         849.000000
# 11         853.000000
# 12         924.000000
# 13         923.000000
# 14         941.000000
# 15         702.000000
# 16         854.000000
# 17         851.000000
# 18         837.000000
# 19         844.000000
# 20         812.000000
# 21         821.000000
# 22         858.000000
# 23         837.000000
# 24         858.000000
# 25         807.000000
# 26         945.000000
# 27         925.000000
# 28        1039.000000
# 29         833.000000
#              ...
# 336746    2223.000000
# 336747    2314.000000
# 336748    2328.000000
# 336749    2230.000000
# 336750    2225.000000
# 336751      10.000000
# 336752    2250.000000
# 336753     115.000000
# 336754      30.000000
# 336755    2245.000000
# ...

# %%
n.loc[11264:11280, ]
# Out:
# 11264    1502.054999
# 11265    1502.054999
# 11266    1502.054999
# 11267    1502.054999
# 11268    1502.054999
# 11269    1502.054999
# 11270    1502.054999
# 11271    1502.054999
# 11272    1502.054999
# 11273    1502.054999
# 11274    1502.054999
# 11275    1502.054999
# 11276    1502.054999
# 11277    1502.054999
# 11278    1502.054999
# 11279    1502.054999
# 11280     640.000000
# Name: arr_time, dtype: float64

# %%
o = Flight["arr_delay"].fillna(j)
print(o)
# Out:
# 0          11.000000
# 1          20.000000
# 2          33.000000
# 3         -18.000000
# 4         -25.000000
# 5          12.000000
# 6          19.000000
# 7         -14.000000
# 8          -8.000000
# 9           8.000000
# 10         -2.000000
# 11         -3.000000
# 12          7.000000
# 13        -14.000000
# 14         31.000000
# 15         -4.000000
# 16         -8.000000
# 17         -7.000000
# 18         12.000000
# 19         -6.000000
# 20         -8.000000
# 21         16.000000
# 22        -12.000000
# 23         -8.000000
# 24        -17.000000
# 25         32.000000
# 26         14.000000
# 27          4.000000
# 28        -21.000000
# 29         -9.000000
#              ...
# 336746    -24.000000
# 336747     -9.000000
# 336748    -31.000000
# 336749     -2.000000
# 336750    -30.000000
# 336751    -30.000000
# 336752     11.000000
# 336753    -25.000000
# 336754      3.000000
# 336755    -23.000000
# 336756    -16.000000
# 336757    194.000000
# ...

# %%
o.loc[2689:2700, ]
# Out:
# 2689      6.895377
# 2690      6.895377
# 2691      6.895377
# 2692      6.895377
# 2693      6.895377
# 2694      6.895377
# 2695      6.895377
# 2696      6.895377
# 2697      6.895377
# 2698      6.895377
# 2699     23.000000
# 2700    125.000000
# Name: arr_delay, dtype: float64

# %%
p = Flight["air_time"].fillna(k)
print(p)
# Out:
# 0         227.00000
# 1         227.00000
# 2         160.00000
# 3         183.00000
# 4         116.00000
# 5         150.00000
# 6         158.00000
# 7          53.00000
# 8         140.00000
# 9         138.00000
# 10        149.00000
# 11        158.00000
# 12        345.00000
# 13        361.00000
# 14        257.00000
# 15         44.00000
# 16        337.00000
# 17        152.00000
# 18        134.00000
# 19        147.00000
# 20        170.00000
# 21        105.00000
# 22        152.00000
# 23        128.00000
# 24        157.00000
# 25        139.00000
# 26        366.00000
# 27        175.00000
# 28        182.00000
# 29        120.00000
#             ...
# 336746     45.00000
# 336747     72.00000
# 336748    213.00000
# 336749     45.00000
# 336750     36.00000
# 336751    298.00000
# 336752     47.00000
# 336753    192.00000
# 336754    139.00000
# 336755     37.00000
# 336756     39.00000
# 336757     50.00000
# 336758     61.00000
# 336759     97.00000
# ...

# %%
p.loc[13958:13986, ]
# Out:
# 13958    150.68646
# 13959    150.68646
# 13960    150.68646
# 13961    150.68646
# 13962    150.68646
# 13963    150.68646
# 13964    150.68646
# 13965    150.68646
# 13966    150.68646
# 13967    150.68646
# 13968    150.68646
# 13969    150.68646
# 13970    150.68646
# 13971    150.68646
# 13972    150.68646
# 13973    150.68646
# 13974    150.68646
# 13975    150.68646
# 13976    150.68646
# 13977    150.68646
# 13978    150.68646
# 13979    150.68646
# 13980    150.68646
# 13981    150.68646
# 13982    150.68646
# 13983    150.68646
# 13984    150.68646
# 13985    150.68646
# 13986    150.68646
# Name: air_time, dtype: float64

# %%
#Now that I have cleaned the columns with missing data, I need to removed the columns with missing data from the original dataframe
#I also dropped the tailnum column because it has missing values and does not provide value for the requested analysis

FlightN2 = Flight.filter(['Column1', 'year', 'month', 'day', 'sched_dep_time', 'sched_arr_time', 'carrier', 'flight', 'origin', 'dest', 'distance', 'hour', 'minute', 'time_hour'], axis=1)
print(FlightN2)
# Out:
#         Column1  year  month  day  sched_dep_time  sched_arr_time carrier  \
# 0             1  2013      1    1             515             819      UA
# 1             2  2013      1    1             529             830      UA
# 2             3  2013      1    1             540             850      AA
# 3             4  2013      1    1             545            1022      B6
# 4             5  2013      1    1             600             837      DL
# 5             6  2013      1    1             558             728      UA
# 6             7  2013      1    1             600             854      B6
# 7             8  2013      1    1             600             723      EV
# 8             9  2013      1    1             600             846      B6
# 9            10  2013      1    1             600             745      AA
# 10           11  2013      1    1             600             851      B6
# 11           12  2013      1    1             600             856      B6
# ...

# %%
#I also need to add the cleaned columns back to the data frame
#one column at a time first

FlightN3 = FlightN2.assign(dep_time=l.values)
print(FlightN3)
# Out:
#         Column1  year  month  day  sched_dep_time  sched_arr_time carrier  \
# 0             1  2013      1    1             515             819      UA
# 1             2  2013      1    1             529             830      UA
# 2             3  2013      1    1             540             850      AA
# 3             4  2013      1    1             545            1022      B6
# 4             5  2013      1    1             600             837      DL
# 5             6  2013      1    1             558             728      UA
# 6             7  2013      1    1             600             854      B6
# 7             8  2013      1    1             600             723      EV
# 8             9  2013      1    1             600             846      B6
# 9            10  2013      1    1             600             745      AA
# 10           11  2013      1    1             600             851      B6
# 11           12  2013      1    1             600             856      B6
# ...

# %%
#Now I will assign the remaining cleaned columns to the dataframe

FlightN4 = FlightN3.assign(dep_delay=m.values, arr_time=n.values, arr_delay=o.values, air_time=p.values)
print(FlightN4)
# Out:
#         Column1  year  month  day  sched_dep_time  sched_arr_time carrier  \
# 0             1  2013      1    1             515             819      UA
# 1             2  2013      1    1             529             830      UA
# 2             3  2013      1    1             540             850      AA
# 3             4  2013      1    1             545            1022      B6
# 4             5  2013      1    1             600             837      DL
# 5             6  2013      1    1             558             728      UA
# 6             7  2013      1    1             600             854      B6
# 7             8  2013      1    1             600             723      EV
# 8             9  2013      1    1             600             846      B6
# 9            10  2013      1    1             600             745      AA
# 10           11  2013      1    1             600             851      B6
# 11           12  2013      1    1             600             856      B6
# ...

# %%
#I want the cleaned dataframe to be called FlightC

FlightC = FlightN4
print(FlightC)
# Out:
#         Column1  year  month  day  sched_dep_time  sched_arr_time carrier  \
# 0             1  2013      1    1             515             819      UA
# 1             2  2013      1    1             529             830      UA
# 2             3  2013      1    1             540             850      AA
# 3             4  2013      1    1             545            1022      B6
# 4             5  2013      1    1             600             837      DL
# 5             6  2013      1    1             558             728      UA
# 6             7  2013      1    1             600             854      B6
# 7             8  2013      1    1             600             723      EV
# 8             9  2013      1    1             600             846      B6
# 9            10  2013      1    1             600             745      AA
# 10           11  2013      1    1             600             851      B6
# 11           12  2013      1    1             600             856      B6
# ...

# %%
#Now I will print row counts for the cleaned dataframes to show that missing values have been removed

PlaneC.count()
# Out:
# tailnum         3322
# year            3252
# type            3322
# manufacturer    3322
# model           3322
# engines         3322
# seats           3322
# engine          3322
# dtype: int64

# %%
PlaneC.shape[0]
# Out:
# 3322

# %%
FlightC.count()
# Out:
# Column1           336776
# year              336776
# month             336776
# day               336776
# sched_dep_time    336776
# sched_arr_time    336776
# carrier           336776
# flight            336776
# origin            336776
# dest              336776
# distance          336776
# hour              336776
# minute            336776
# time_hour         336776
# dep_time          336776
# air_time          336776
# arr_delay         336776
# arr_time          336776
# dep_delay         336776
# dtype: int64

# %%
FlightC.shape[0]
# Out:
# 336776

# %%
WeatherC.count()
# Out:
# origin        26130
# year          26130
# month         26130
# day           26130
# hour          26130
# precip        26130
# visib         26130
# time_hour     26130
# temp          26130
# dewp          26130
# humid         26130
# pressure      26130
# wind_dir      26130
# wind_gust     26130
# wind_speed    26130
# dtype: int64

# %%
WeatherC.shape[0]
# Out:
# 26130

# %%
#This shows that all of the missing values are removed from the cleaned dataframes.

# %%
#Part A - ii
#Now I will find the top 5 busiest airports based on average number of arrivals per day

k = FlightC.groupby('dest').count()
print(k)
# Out:
#       Column1   year  month    day  sched_dep_time  sched_arr_time  carrier  \
# dest
# ABQ       254    254    254    254             254             254      254
# ACK       265    265    265    265             265             265      265
# ALB       439    439    439    439             439             439      439
# ANC         8      8      8      8               8               8        8
# ATL     17215  17215  17215  17215           17215           17215    17215
# AUS      2439   2439   2439   2439            2439            2439     2439
# AVL       275    275    275    275             275             275      275
# BDL       443    443    443    443             443             443      443
# BGR       375    375    375    375             375             375      375
# BHM       297    297    297    297             297             297      297
# BNA      6333   6333   6333   6333            6333            6333     6333
# ...

# %%
#by sorting the counts from high to low, we see that ORD (O'hare), ATL (Atlanta), LAX (Los Angeles), BOS (Boston), and MCO (Orlando) have the most arrivals during 2013.
#all of the airports in the data set operate 365 days per year, so the airports with the highest total counts will also have the highest average arrivals per day.

k.sort_values(by=['Column1'], ascending=False)
# Out:
#       Column1   year  month    day  sched_dep_time  sched_arr_time  carrier  \
# dest
# ORD     17283  17283  17283  17283           17283           17283    17283
# ATL     17215  17215  17215  17215           17215           17215    17215
# LAX     16174  16174  16174  16174           16174           16174    16174
# BOS     15508  15508  15508  15508           15508           15508    15508
# MCO     14082  14082  14082  14082           14082           14082    14082
# CLT     14064  14064  14064  14064           14064           14064    14064
# SFO     13331  13331  13331  13331           13331           13331    13331
# FLL     12055  12055  12055  12055           12055           12055    12055
# MIA     11728  11728  11728  11728           11728           11728    11728
# DCA      9705   9705   9705   9705            9705            9705     9705
# DTW      9384   9384   9384   9384            9384            9384     9384
# ...

# %%
#I can just not make the datetime conversions to find the inter-arrival times. I spent hours on this to no avail.

# %%
#Part A - iii
#I cannot plot the inter-arrival times because I cannot get the datetime conversions to work.

# %%
#Upon completion of the data cleaning portion, I converted the cleaned data files into a csv file for import into mySQL
#These csv files got saved to my current working directory, and I was able to attempt the data import into mySQL - See Part B file

FlightC5.to_csv('FlightC5.csv')

# %%
WeatherC3.to_csv('WeatherC3.csv')

# %%
PlaneC.to_csv('PlaneC2.csv')
