# %%
import mysql.connector
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
FW = pd.read_csv('C:/Users/Justin/Documents/Grad Courses/DNSC 6211 - Programming for Analytics/Week 10/Assignment 9/FW.csv')

# %%
FW.head(n=5)
# Out:
#    idweather  precip  visib  temp  dewp  humid  pressure  wind_dur  wind_gust  \
# 0          5       0     10    39    26     59      1012       270         11
# 1          5       0     10    39    26     59      1012       270         11
# 2          5       0     10    39    26     59      1012       270         11
# 3          5       0     10    39    26     59      1012       270         11
# 4          5       0     10    39    26     59      1012       270         11
#
#    wind_speed    ...      dest  distance  hour.1 minute time_hour.1  dep_time  \
# 0          10    ...       FLL      1065       6      0         555       158
# 1          10    ...       SFO      2565       6      0         558       361
# 2          10    ...       LAS      2227       6      0         559       337
# 3          10    ...       PBI      1023       6      0         601       147
# 4          10    ...       MIA      1085       6     10         606       152
#
#    air_time  arr_delay  arr_time  dep_delay
# 0        19        913        -5        NaN
# 1       -14        923        -2        NaN
# 2        -8        854        -1        NaN
# 3        -6        844         1        NaN
# 4       -12        858        -4        NaN
#
# [5 rows x 36 columns]

# %%
#returns something but without values

FW.loc[FW['origin'].isin(list('JFK'))]
# Out:
# Empty DataFrame
# Columns: [idweather, precip, visib, temp, dewp, humid, pressure, wind_dur, wind_gust, wind_speed, day, hour, month, origin, time_hour, year, idflights, Column1, year.1, month.1, day.1, sched_dep_time, sched_arr_time, carrier, flight, origin.1, dest, distance, hour.1, minute, time_hour.1, dep_time, air_time, arr_delay, arr_time, dep_delay]
# Index: []
#
# [0 rows x 36 columns]

# %%
FW.loc[FW['origin'] == 'JFK']
# Out:
# Empty DataFrame
# Columns: [idweather, precip, visib, temp, dewp, humid, pressure, wind_dur, wind_gust, wind_speed, day, hour, month, origin, time_hour, year, idflights, Column1, year.1, month.1, day.1, sched_dep_time, sched_arr_time, carrier, flight, origin.1, dest, distance, hour.1, minute, time_hour.1, dep_time, air_time, arr_delay, arr_time, dep_delay]
# Index: []
#
# [0 rows x 36 columns]

# %%
FW.loc[FW['humid'] == 53]
# Out:
#       idweather  precip  visib  temp  dewp  humid  pressure  wind_dur  \
# 1328        100       0     10    33    17     53      1017       260
# 1329        100       0     10    33    17     53      1017       260
# 1352        102       0     10    32    17     53      1018       280
# 1353        102       0     10    32    17     53      1018       280
# 1354        102       0     10    32    17     53      1018       280
# 1355        102       0     10    32    17     53      1018       280
# 1356        102       0     10    32    17     53      1018       280
# 1357        102       0     10    32    17     53      1018       280
# 1358        102       0     10    32    17     53      1018       280
# 1359        102       0     10    32    17     53      1018       280
# 1360        102       0     10    32    17     53      1018       280
# 1361        102       0     10    32    17     53      1018       280
# 1362        102       0     10    32    17     53      1018       280
# 1363        102       0     10    32    17     53      1018       280
# 1364        102       0     10    32    17     53      1018       280
# 1365        102       0     10    32    17     53      1018       280
# 1366        103       0     10    32    17     53      1019       290
# 1367        103       0     10    32    17     53      1019       290
# 1368        103       0     10    32    17     53      1019       290
# 1369        103       0     10    32    17     53      1019       290
# 1371        103       0     10    32    17     53      1019       290
# 1372        103       0     10    32    17     53      1019       290
# 1373        103       0     10    32    17     53      1019       290
# 1374        103       0     10    32    17     53      1019       290
# 1375        102       0     10    32    17     53      1018       280
# 1376        103       0     10    32    17     53      1019       290
# 1377        103       0     10    32    17     53      1019       290
# 1378        103       0     10    32    17     53      1019       290
# 1379        103       0     10    32    17     53      1019       290
# 1380        103       0     10    32    17     53      1019       290
# ...         ...     ...    ...   ...   ...    ...       ...       ...
# 1417        105       0     10    32    17     53      1021       240
# 1418        106       0     10    33    17     53      1022       250
# 1419        106       0     10    33    17     53      1022       250
# 1420        106       0     10    33    17     53      1022       250
# 1421        106       0     10    33    17     53      1022       250
# 1422        105       0     10    32    17     53      1021       240
# 1423        106       0     10    33    17     53      1022       250
# 1424        106       0     10    33    17     53      1022       250
# 1425        106       0     10    33    17     53      1022       250
# 1426        106       0     10    33    17     53      1022       250
# 1439        108       0     10    35    19     53      1024       240
# 1440        106       0     10    33    17     53      1022       250
# 1441        108       0     10    35    19     53      1024       240
# 1442        108       0     10    35    19     53      1024       240
# 1443        108       0     10    35    19     53      1024       240
# 1444        108       0     10    35    19     53      1024       240
# 1445        108       0     10    35    19     53      1024       240
# 1446        108       0     10    35    19     53      1024       240
# 1447        108       0     10    35    19     53      1024       240
# 1448        108       0     10    35    19     53      1024       240
# 1449        108       0     10    35    19     53      1024       240
# 1450        108       0     10    35    19     53      1024       240
# 1451        108       0     10    35    19     53      1024       240
# 1452        108       0     10    35    19     53      1024       240
# 1453        108       0     10    35    19     53      1024       240
# 1454        108       0     10    35    19     53      1024       240
# 1455        108       0     10    35    19     53      1024       240
# 1456        108       0     10    35    19     53      1024       240
# 1458        108       0     10    35    19     53      1024       240
# 1460        108       0     10    35    19     53      1024       240
#
#       wind_gust  wind_speed    ...      dest  distance  hour.1 minute  \
# 1328         11          10    ...       CLT       529       5      0
# 1329         11          10    ...       IAH      1400       5     15
# 1352         14          12    ...       HOU      1411       7      0
# 1353         14          12    ...       ORD       719       7     10
# 1354         14          12    ...       LAS      2227       7     11
# 1355         14          12    ...       LAX      2454       7     10
# 1356         14          12    ...       STT      1634       7     23
# 1357         14          12    ...       MCO       937       7     10
# 1358         14          12    ...       BWI       169       7     22
# 1359         14          12    ...       SEA      2402       7     25
# 1360         14          12    ...       STL       872       7     30
# 1361         14          12    ...       ATL       746       7     30
# 1362         14          12    ...       SJU      1608       7     45
# 1363         14          12    ...       TPA       997       7     29
# 1364         14          12    ...       IAH      1400       7     46
# 1365         14          12    ...       BUF       282       7     57
# 1366         21          18    ...       MSP      1008       8      0
# 1367         21          18    ...       MCO       937       8      0
# 1368         21          18    ...       BOS       200       8      5
# 1369         21          18    ...       ROC       246       8      9
# 1371         21          18    ...       PHX      2133       8      0
# 1372         21          18    ...       CLT       529       8     15
# 1373         21          18    ...       MYR       550       8     11
# 1374         21          18    ...       FLL      1065       8     22
# 1375         14          12    ...       MHT       209       7     59
# 1376         21          18    ...       HDN      1728       8     30
# 1377         21          18    ...       RDU       416       8     35
# 1378         21          18    ...       MDW       711       8     30
# 1379         21          18    ...       BOS       200       8     40
# 1380         21          18    ...       DTW       488       8     38
# ...         ...         ...    ...       ...       ...     ...    ...
# 1417         14          12    ...       SEA      2402      10     55
# 1418         11          10    ...       DEN      1605      11     30
# 1419         11          10    ...       STL       872      11     30
# 1420         11          10    ...       MIA      1085      11     40
# 1421         11          10    ...       BTV       266      11     46
# 1422         14          12    ...       SFO      2565      10     59
# 1423         11          10    ...       MCO       937      11     30
# 1424         11          10    ...       TPA       997      11     42
# 1425         11          10    ...       JAX       820      11     52
# 1426         11          10    ...       SJU      1608      11     25
# 1439         10           9    ...       SLC      1969      13      0
# 1440         11          10    ...       PBI      1023      11     27
# 1441         10           9    ...       DCA       199      13      5
# 1442         10           9    ...       ORD       719      13      0
# 1443         10           9    ...       RIC       277      13      0
# 1444         10           9    ...       LAX      2454      13     15
# 1445         10           9    ...       HOU      1411      13     20
# 1446         10           9    ...       CLT       529      13     15
# 1447         10           9    ...       BDL       116      13     25
# 1448         10           9    ...       BWI       169      13     28
# 1449         10           9    ...       FLL      1065      13     15
# 1450         10           9    ...       BTV       266      13     29
# 1451         10           9    ...       MIA      1085      13     26
# 1452         10           9    ...       MCO       937      13     40
# 1453         10           9    ...       HNL      4963      13     35
# 1454         10           9    ...       PHX      2133      13     40
# 1455         10           9    ...       PHX      2133      13     45
# 1456         10           9    ...       MCO       937      13     50
# 1458         10           9    ...       PHX      2133      13     50
# 1460         10           9    ...       IAH      1400      13     59
#
#      time_hour.1  dep_time  air_time  arr_delay  arr_time  dep_delay
# 1328         458        85       -10        640        -2        NaN
# 1329         516       226         5        821         1        NaN
# 1352         704       228         3       1013         4        NaN
# 1353         708       120        -9        841        -2        NaN
# 1354         710       309       -16        941        -1        NaN
# 1355         710       336       -14       1017         0        NaN
# 1356         718       203       -21       1201        -5        NaN
# 1357         724       136        -3       1000        14        NaN
# 1358         725        32        -6        824         3        NaN
# 1359         725       330       -19       1011         0        NaN
# 1360         726       149         9        930        -4        NaN
# 1361         727       115       -23        941        -3        NaN
# 1362         742       197       -14       1220        -3        NaN
# 1363         745       148         1       1030        16        NaN
# 1364         746       230        10       1101         0        NaN
# 1365         751        56       -13        903        -6        NaN
# 1366         755       154       -24        944        -5        NaN
# 1367         755       135       -15       1039        -5        NaN
# 1368         757        43       -22        857        -8        NaN
# 1369         805        47       -16        914        -4        NaN
# 1371         811       306        -6       1139        11        NaN
# 1372         811        86       -18        958        -4        NaN
# 1373         813        84       -22        953         2        NaN
# 1374         821       156       -15       1114        -1        NaN
# 1375         822        40        20        929        23        NaN
# 1376         829       243       -24       1047        -1        NaN
# 1377         833        66       -20       1005        -2        NaN
# 1378         834       122         1        956         4        NaN
# 1379         835        42       -19        939        -5        NaN
# 1380         836        92       -13       1031        -2        NaN
# ...          ...       ...       ...        ...       ...        ...
# 1417        1124       327        -3       1410        29        NaN
# 1418        1132       239        11       1407         2        NaN
# 1419        1134       148        -5       1315         4        NaN
# 1420        1137       153       -19       1426        -3        NaN
# 1421        1141        53        -7       1249        -5        NaN
# 1422        1141       338        11       1442        42        NaN
# 1423        1141       144         5       1427        11        NaN
# 1424        1143       161         2       1441         1        NaN
# 1425        1149       131        -7       1417        -3        NaN
# 1426        1151       197        10       1628        26        NaN
# 1439        1255       279       -17       1551        -5        NaN
# 1440        1301       167        98       1605        94        NaN
# 1441        1303        48        -2       1404        -2        NaN
# 1442        1303       122       -11       1426         3        NaN
# 1443        1304        52        -6       1415         4        NaN
# 1444        1311       335       -13       1610        -4        NaN
# 1445        1320       231        20       1645         0        NaN
# 1446        1321        88         4       1509         6        NaN
# 1447        1323        23       -23       1358        -2        NaN
# 1448        1326        39        -9       1421        -2        NaN
# 1449        1326       157        12       1623        11        NaN
# 1450        1327        45       -10       1429        -2        NaN
# 1451        1328       162         5       1634         2        NaN
# 1452        1329       143        -8       1618       -11        NaN
# 1453        1329       600       -45       1850        -6        NaN
# 1454        1335       307       -11       1704        -5        NaN
# 1455        1345       301       -10       1707         0        NaN
# 1456        1348       150        -6       1646        -2        NaN
# 1458        1351       295       -17       1658         1        NaN
# 1460        1406       221        19       1715         7        NaN
#
# [96 rows x 36 columns]

# %%
FW['origin']
# Out:
# 0       EWR
# 1       EWR
# 2       EWR
# 3       EWR
# 4       EWR
# 5       EWR
# 6       EWR
# 7       EWR
# 8       EWR
# 9       EWR
# 10      EWR
# 11      EWR
# 12      EWR
# 13      EWR
# 14      EWR
# 15      EWR
# 16      EWR
# 17      EWR
# 18      EWR
# 19      EWR
# 20      EWR
# 21      EWR
# 22      EWR
# 23      EWR
# 24      EWR
# 25      EWR
# 26      EWR
# 27      EWR
# 28      EWR
# 29      EWR
#        ...
# 1970    EWR
# 1971    EWR
# 1972    EWR
# 1973    EWR
# 1974    EWR
# 1975    EWR
# 1976    EWR
# 1977    EWR
# 1978    EWR
# 1979    EWR
# 1980    EWR
# 1981    EWR
# 1982    EWR
# 1983    EWR
# 1984    EWR
# 1985    EWR
# 1986    EWR
# 1987    EWR
# 1988    EWR
# 1989    EWR
# 1990    EWR
# 1991    EWR
# 1992    EWR
# 1993    EWR
# 1994    EWR
# 1995    EWR
# 1996    EWR
# 1997    EWR
# 1998    EWR
# 1999    EWR
# Name: origin, Length: 2000, dtype: object

# %%
JFK = pd.read_csv('C:/Users/Justin/Documents/Grad Courses/DNSC 6211 - Programming for Analytics/Week 10/Assignment 9/JFK.csv')

# %%
JFK.head(n=5)
# Out:
#    idweather  precip  visib  temp  dewp  humid  pressure  wind_dur  wind_gust  \
# 0       8713       0     10    39    26     59      1012       260         14
# 1       8713       0     10    39    26     59      1012       260         14
# 2       8713       0     10    39    26     59      1012       260         14
# 3       8713       0     10    39    26     59      1012       260         14
# 4       8713       0     10    39    26     59      1012       260         14
#
#    wind_speed    ...      dest  distance  hour.1 minute time_hour.1  dep_time  \
# 0          12    ...       MCO       944       6      0         557       140
# 1          12    ...       PBI      1028       6      0         558       149
# 2          12    ...       TPA      1005       6      0         558       158
# 3          12    ...       LAX      2475       6      0         558       345
# 4          12    ...       ATL       760       6     10         606       128
#
#    air_time  arr_delay  arr_time  dep_delay
# 0        -8        838        -3        NaN
# 1        -2        849        -2        NaN
# 2        -3        853        -2        NaN
# 3         7        924        -2        NaN
# 4        -8        837        -4        NaN
#
# [5 rows x 36 columns]

# %%
JFK['sched_dep_time'] - JFK['dep_time']
# Out:
# 0        460
# 1        451
# 2        442
# 3        255
# 4        482
# 5        234
# 6        435
# 7        433
# 8        300
# 9        438
# 10       599
# 11       584
# 12       332
# 13       464
# 14       361
# 15       338
# 16       517
# 17       339
# 18       544
# 19       319
# 20       525
# 21       556
# 22       574
# 23       374
# 24       671
# 25       682
# 26       387
# 27       372
# 28       585
# 29       381
#         ...
# 1970    1113
# 1971     852
# 1972    1162
# 1973     898
# 1974    1159
# 1975    1161
# 1976     958
# 1977    1211
# 1978    1085
# 1979    1214
# 1980    1275
# 1981     995
# 1982    1106
# 1983    1247
# 1984    1151
# 1985    1127
# 1986     519
# 1987    1218
# 1988    1004
# 1989    1299
# 1990     984
# 1991    1008
# 1992    1205
# 1993    1310
# 1994    1256
# 1995    1379
# 1996    1092
# 1997    1092
# 1998    1280
# 1999    1293
# Length: 2000, dtype: int64

# %%
JFK['arr_time'] > 10.any(axis=1)
# Out:
#   File "<ipython-input-53-d60859aabe68>", line 1
#     JFK['arr_time'] > 10.any
#                            ^
# SyntaxError: invalid syntax

# %%
JFK2 = JFK[JFK.arr_time > 10]
JFK2.head(n=10)

#works!!
# Out:
#     idweather  precip  visib  temp  dewp  humid  pressure  wind_dur  \
# 5        8713       0     10    39    26     59      1012       260
# 27       8714       0     10    39    26     59      1012       270
# 29       8714       0     10    39    26     59      1012       270
# 48       8714       0     10    39    26     59      1012       270
# 53       8725       0     10    37    26     64      1017       340
# 60       8715       0     10    39    26     59      1012       260
# 61       8716       0     10    39    28     62      1012       250
# 64       8716       0     10    39    28     62      1012       250
# 65       8716       0     10    39    28     62      1012       250
# 70       8716       0     10    39    28     62      1012       250
#
#     wind_gust  wind_speed    ...      dest  distance  hour.1 minute  \
# 5          14          12    ...       SFO      2586       6      0
# 27         13          11    ...       LAX      2475       7     30
# 29         13          11    ...       SEA      2422       7     30
# 48         13          11    ...       MIA      1089       7     15
# 53         17          14    ...       BWI       184      18     35
# 60         17          14    ...       STT      1623       8     10
# 61         19          17    ...       MIA      1089       9      0
# 64         19          17    ...       IAD       228       9      5
# 65         19          17    ...       LAX      2475       9      0
# 70         19          17    ...       FLL      1069       9      4
#
#    time_hour.1  dep_time  air_time  arr_delay  arr_time  dep_delay
# 5          611       366        14        945        11        NaN
# 27         743       358         7       1107        13        NaN
# 29         743       349         3       1059        13        NaN
# 48         826       160        51       1136        71        NaN
# 53         848        41       851       1001       853        NaN
# 60         909       184        16       1331        59        NaN
# 61         912       166        21       1241        12        NaN
# 64         920        52        14       1039        15        NaN
# 65         921       333        10       1237        21        NaN
# 70         933       170        42       1252        29        NaN
#
# [10 rows x 36 columns]

# %%
#calling the new table that provides JFK flights delayed by greater than 10 minutes as mydelay

mydelay = JFK2
mydelay.head(n=5)
# Out:
#     idweather  precip  visib  temp  dewp  humid  pressure  wind_dur  \
# 5        8713       0     10    39    26     59      1012       260
# 27       8714       0     10    39    26     59      1012       270
# 29       8714       0     10    39    26     59      1012       270
# 48       8714       0     10    39    26     59      1012       270
# 53       8725       0     10    37    26     64      1017       340
#
#     wind_gust  wind_speed    ...      dest  distance  hour.1 minute  \
# 5          14          12    ...       SFO      2586       6      0
# 27         13          11    ...       LAX      2475       7     30
# 29         13          11    ...       SEA      2422       7     30
# 48         13          11    ...       MIA      1089       7     15
# 53         17          14    ...       BWI       184      18     35
#
#    time_hour.1  dep_time  air_time  arr_delay  arr_time  dep_delay
# 5          611       366        14        945        11        NaN
# 27         743       358         7       1107        13        NaN
# 29         743       349         3       1059        13        NaN
# 48         826       160        51       1136        71        NaN
# 53         848        41       851       1001       853        NaN
#
# [5 rows x 36 columns]

# %%
#find the mean of temperature, humidity, wind speed, and precipitation for flights departing from JFK that were delayed by more than 10 minutes.

aa = mydelay['temp'].mean()
bb = mydelay['humid'].mean()
cc = mydelay['wind_speed'].mean()
dd = mydelay['precip'].mean()
print(aa, bb, cc, dd)
# Out:
# 34.7308533916849 52.37199124726477 12.969365426695843 0.0

# %%
mydelay['temp'].plot()

# %%
#plotting distributions for the different weather variables

plt.plot(mydelay['temp'])
plt.show()

# %%
plt.plot(mydelay['humid'])
plt.show()

# %%
plt.plot(mydelay['wind_speed'])
plt.show()

# %%
plt.plot(mydelay['precip'])
plt.show()

# %%
#saving my delay as a csv file!!

mydelay.to_csv('mydelay.csv')
