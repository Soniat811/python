# %% [markdown]
# **Setup**
#
# 1. Install chromium browser, beautifulsoup and requests
#     1. sudo apt-get install chromium-browser
#     + conda install beautifulsoup4
#     + conda install requests
# + Make sure all the files are available in the folder that you are working with

# %%
# Slide 5
# Open "Files" file organizer
# Right-click on "simple.html"
# Right-click on document and "inspect"

# %%
#path = "C:/Users/kanungo/odrive/Google Drive/mydata/Courses/Programming for analytics/Fall 2017/Slides PPT/Week 11 - Web scraping/code and materials/files/"
path = "C:/Users/Justin/Documents/Grad Courses/DNSC 6211 - Programming for Analytics/Week 11/Web Scraping slides/files/"
#path to the files folder
#windows path...
#path = "/home/drk/kanungo/DNSC6211/week11/code and materials/files/"

# %%
# Slide 17
import urllib.request
url = "http://www.google.com/"
request = urllib.request.Request(url)
#establishes the connection
response = urllib.request.urlopen(request)
#opens the connected file
print (response.info())
html = response.read()
# print (html)                   #  <-- Try this out 
response.close()                 # best to close the file
# Out:
# Date: Fri, 10 Nov 2017 01:07:03 GMT
# Expires: -1
# Cache-Control: private, max-age=0
# Content-Type: text/html; charset=ISO-8859-1
# P3P: CP="This is not a P3P policy! See g.co/p3phelp for more info."
# Server: gws
# X-XSS-Protection: 1; mode=block
# X-Frame-Options: SAMEORIGIN
# Set-Cookie: 1P_JAR=2017-11-10-01; expires=Sun, 10-Dec-2017 01:07:03 GMT; path=/; domain=.google.com
# Set-Cookie: NID=116=D9VtNOX_u6EAwl0FlEwyVwR7KJ5HE-lIJbP2G3-IeBWi1ewbvrDHJOM8FTZxY-coktHmRk1r21e9wfAw7WIc46yoUNecTlJePuJLs6tE1Q60TnfPjfI46-APQNLH6yO8; expires=Sat, 12-May-2018 01:07:03 GMT; path=/; domain=.google.com; HttpOnly
# Accept-Ranges: none
# Vary: Accept-Encoding
# Connection: close

# %%
# Slide 18
import urllib.request
filename = "simple.html"
url = "file:///"+path+filename
request = urllib.request.Request(url)
response = urllib.request.urlopen(request)
data = response.read()
print (data)
response.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\urllib\request.py in open_local_file(self, req)
#    1473         try:
# -> 1474             stats = os.stat(localfile)
#    1475             size = stats.st_size
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\Justin\\Documents\\Grad Courses\\DNSC 6211 - Programming for Analytics\\Week 11\\Web Scraping slides\\files\\simple.html'
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-7-9b38eff65af4> in <module>()
#       4 url = "file:///"+path+filename
#       5 request = urllib.request.Request(url)
# ----> 6 response = urllib.request.urlopen(request)
#       7 data = response.read()
#       8 print (data)
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\Anaconda3\lib\urllib\request.py in file_open(self, req)
#    1450                 raise URLError("file:// scheme is supported only on localhost")
#    1451         else:
# -> 1452             return self.open_local_file(req)
#    1453
#    1454     # names for the localhost
#
# ~\Anaconda3\lib\urllib\request.py in open_local_file(self, req)
#    1489                 return addinfourl(open(localfile, 'rb'), headers, origurl)
#    1490         except OSError as exp:
# -> 1491             raise URLError(exp)
#    1492         raise URLError('file not on local host')
#    1493
#
# URLError: <urlopen error [WinError 3] The system cannot find the path specified: 'C:\\Users\\Justin\\Documents\\Grad Courses\\DNSC 6211 - Programming for Analytics\\Week 11\\Web Scraping slides\\files\\simple.html'>

# %%
# Slide 20
# Next few cells
# Before you go to the next few cells
#    Go to www.gwu.edu
#    Explore the page using inspect (in any browser)
#    Look for all the <a> tags

# %%
from bs4 import BeautifulSoup as bs

# %%
import requests

# %%
r = requests.get("http://www.gwu.edu")

# %%
data = r.text

# %%
soup = bs(data, "html.parser")

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# #main-content
# https://students.gwu.edu/?utm_source=utilitynav&utm_medium=audience-students&utm_campaign=gwhomepage-utility
# https://www.gwu.edu/faculty-staff
# https://alumni.gwu.edu/?utm_source=utilitynav&utm_medium=audience-alumni&utm_campaign=gwhomepage-utility
# https://www.gwu.edu/email
# https://banweb.gwu.edu?utm_source=utilitynav&utm_medium=task-gweb&utm_campaign=gwhomepage-utility
# https://blackboard.gwu.edu/webapps/login/?new_loc=/webapps/portal/execute/defaultTab%3Futm_source%3Dutilitynav&utm_medium=task-utility&utm_campaign=gwhomepage-utility
# http://my.gwu.edu/mod/directory?utm_source=utilitynav&utm_medium=task-directoryi&utm_campaign=gwhomepage-utility
# https://giving.gwu.edu?utm_source=utilitynav&utm_medium=task-give&utm_campaign=gwhomepage-utility
# https://www.gwu.edu
# https://www.gwu.edu/admissions-aid
# https://www.gwu.edu
# https://www.gwu.edu/admissions-aid
# /about
# /leadership
# /our-priorities
# /our-location
# /foggy-bottom-campus
# /mount-vernon-campus
# /virginia-science-technology-campus
# /online-virginia-academic-centers
# /admissions-aid
# /undergraduate-admissions
# /graduate-admissions
# /academics
# /schools-colleges
# /academic-calendar
# /research
# /research-resources
# /gw-experience
# /campus-life
# /traditions
# /internships
# /athletics-recreation
# /campus-health
# /arts-culture
# None
# https://programs.gwu.edu/
# node/43
# node/15
# /player.vimeo.com/video/228264353?autopause=1&autoplay=0&badge=1&byline=1&loop=0&portrait=1&autopause=1&fullscreen=1
# https://president.gwu.edu/
# /academics
# https://gwtoday.gwu.edu?utm_source=gwtoday-header&utm_medium=gwtoday-logo&utm_campaign=gwhomepage-gwtoday
# https://gwtoday.gwu.edu/how-i-got-job-aisha-azimi-aims-make-global-impact?utm_source=GW%20Today%20Section&utm_medium=GWToday_MainStory%202&utm_campaign=gwhomepage-gwtoday
# https://gwtoday.gwu.edu/gw-community-comes-together-16th-annual-interfaith-dinner?utm_source=GW%20Today%20Section&utm_medium=Link1&utm_campaign=gwhomepage-gwtoday
# https://gwtoday.gwu.edu/opioid-addiction-has-wide-ranging-impact?utm_source=GW%20Today%20Section&utm_medium=Link2&utm_campaign=gwhomepage-gwtoday
# https://gwtoday.gwu.edu/gw-receives-41-million-grant-support-diverse-doctoral-students?utm_medium=Link3&utm_campaign=gwhomepage-gwtoday
# /frontpage?qt-events_feed_homepage=0#qt-events_feed_homepage
# http://browse.calendar.gwu.edu/EventList.aspx?view=EventDetails&eventidn=15063&information_id=28314&type=&rss=rss
# http://browse.calendar.gwu.edu/EventList.aspx?view=EventDetails&eventidn=15267&information_id=28747&type=&rss=rss
# http://browse.calendar.gwu.edu/EventList.aspx?view=EventDetails&eventidn=15064&information_id=28316&type=&rss=rss
# http://browse.calendar.gwu.edu/EventList.aspx?view=EventDetails&eventidn=15280&information_id=28773&type=&rss=rss
# http://calendar.gwu.edu
# https://inauguration.gwu.edu?utm_source=community_stories&utm_medium=top-story&utm_campaign=gwhomepage-flex-space&utm_content=leblanc-inauguration
# https://gwtoday.gwu.edu/hear-eight-recipients-alumni-achievement-award?utm_source=community_stories&utm_medium=2nd_row_left&utm_campaign=gwhomepage-flex-space&utm_content=alumni-achievement
# https://gwtoday.gwu.edu/hear-eight-recipients-alumni-achievement-award?utm_source=community_stories&utm_medium=2nd_row_left&utm_campaign=gwhomepage-flex-space&utm_content=alumni-achievement
# https://museum.gwu.edu/boxproject?utm_source=community_stories&utm_medium=2nd_row_right&utm_campaign=gwhomepage-flex-space&utm_content=box-project
# https://museum.gwu.edu/boxprojectutm_source=community_stories&utm_medium=2nd_row_right&utm_campaign=gwhomepage-flex-space&utm_content=box-project
# https://giving.gwu.edu/?utm_campaign=gwhomepage-footer&utm_source=footer-cta&utm_medium=task-give&utm_content=button-ghost
# https://virtualtour.gwu.edu?utm_campaign=gwhomepage-footer&utm_source=footer-cta&utm_medium=virtualtour&utm_content=button-ghost
# http://www.gwsports.com/?utm_campaign=gwhomepage-footer&utm_source=footer-cta&utm_medium=athletics&utm_content=button-ghost
# https://www.facebook.com/georgewashingtonuniversity/
# https://www.instagram.com/gwuniversity/?hl=en
# https://twitter.com/GWtweets?lang=en
# https://www.youtube.com/user/discovergw
# https://gwtoday.gwu.edu
# https://mediarelations.gwu.edu
# https://magazine.gwu.edu
# https://www.gwu.edu/social-media
# https://calendar.gwu.edu
# https://undergraduate.admissions.gwu.edu/visit-gw
# https://graduate.admissions.gwu.edu/campus-visits
# https://www.gwu.edu/admissions-aid
# https://www.gwu.jobs
# https://www.gwu.edu/az-index
# https://www.gwu.edu/copyright
# http://my.gwu.edu/files/policies/EqualEmploymentOpportunityStatement.pdf
# https://www.gwu.edu/privacy-policy
# https://haven.gwu.edu/gw-policies-title-ix
# https://undocumented.gwu.edu
# https://www.gwu.edu/contact-gw
# https://www.gwu.edu/terms-use
# https://accessibility.gwu.edu
# https://campusadvisories.gwu.edu
# http://www.gwu.edu/

# %%
# Slide 19

# %%
# Slide 22
import urllib.request
from bs4 import BeautifulSoup as bs

#expected to understand the following parts
filename = "simple.html"
url = "file:///"+path+filename
request = urllib.request.Request(url)
response = urllib.request.urlopen(request)
data = response.read()
response.close()

# Create the soup
soup = bs(data, "html.parser")

# Print parse tree
print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\urllib\request.py in open_local_file(self, req)
#    1473         try:
# -> 1474             stats = os.stat(localfile)
#    1475             size = stats.st_size
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\Justin\\Documents\\Grad Courses\\DNSC 6211 - Programming for Analytics\\Week 11\\Web Scraping slides\\files\\simple.html'
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-14-4abf308bfca4> in <module>()
#       7 url = "file:///"+path+filename
#       8 request = urllib.request.Request(url)
# ----> 9 response = urllib.request.urlopen(request)
#      10 data = response.read()
#      11 response.close()
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\Anaconda3\lib\urllib\request.py in file_open(self, req)
#    1450                 raise URLError("file:// scheme is supported only on localhost")
#    1451         else:
# -> 1452             return self.open_local_file(req)
#    1453
#    1454     # names for the localhost
#
# ~\Anaconda3\lib\urllib\request.py in open_local_file(self, req)
#    1489                 return addinfourl(open(localfile, 'rb'), headers, origurl)
#    1490         except OSError as exp:
# -> 1491             raise URLError(exp)
#    1492         raise URLError('file not on local host')
#    1493
#
# URLError: <urlopen error [WinError 3] The system cannot find the path specified: 'C:\\Users\\Justin\\Documents\\Grad Courses\\DNSC 6211 - Programming for Analytics\\Week 11\\Web Scraping slides\\files\\simple.html'>

# %%
# Slide 22
import urllib.request
from bs4 import BeautifulSoup as bs

filename = "multipleparas.html"
url = "file:///"+path+filename
request = urllib.request.Request(url)
response = urllib.request.urlopen(request)
data = response.read()
response.close()

# Create the soup
soup = bs(data, "html.parser")

a = soup.find('p')
b = soup.findAll('p')

print(len(a))
print(len(b))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\urllib\request.py in open_local_file(self, req)
#    1473         try:
# -> 1474             stats = os.stat(localfile)
#    1475             size = stats.st_size
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\Justin\\Documents\\Grad Courses\\DNSC 6211 - Programming for Analytics\\Week 11\\Web Scraping slides\\files\\multipleparas.html'
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-15-3f28defecbd0> in <module>()
#       6 url = "file:///"+path+filename
#       7 request = urllib.request.Request(url)
# ----> 8 response = urllib.request.urlopen(request)
#       9 data = response.read()
#      10 response.close()
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\Anaconda3\lib\urllib\request.py in file_open(self, req)
#    1450                 raise URLError("file:// scheme is supported only on localhost")
#    1451         else:
# -> 1452             return self.open_local_file(req)
#    1453
#    1454     # names for the localhost
#
# ~\Anaconda3\lib\urllib\request.py in open_local_file(self, req)
#    1489                 return addinfourl(open(localfile, 'rb'), headers, origurl)
#    1490         except OSError as exp:
# -> 1491             raise URLError(exp)
#    1492         raise URLError('file not on local host')
#    1493
#
# URLError: <urlopen error [WinError 3] The system cannot find the path specified: 'C:\\Users\\Justin\\Documents\\Grad Courses\\DNSC 6211 - Programming for Analytics\\Week 11\\Web Scraping slides\\files\\multipleparas.html'>

# %%
# Slide 25
import urllib.request
from bs4 import BeautifulSoup as bs

filename = "third.html"
url = "file:///"+path+filename
request = urllib.request.Request(url)
response = urllib.request.urlopen(request)
data = response.read()
response.close()

# Create the soup
soup = bs(data, "html.parser")

soup.li
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\urllib\request.py in open_local_file(self, req)
#    1473         try:
# -> 1474             stats = os.stat(localfile)
#    1475             size = stats.st_size
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\Justin\\Documents\\Grad Courses\\DNSC 6211 - Programming for Analytics\\Week 11\\Web Scraping slides\\files\\third.html'
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-17-d7625af8c7ed> in <module>()
#       6 url = "file:///"+path+filename
#       7 request = urllib.request.Request(url)
# ----> 8 response = urllib.request.urlopen(request)
#       9 data = response.read()
#      10 response.close()
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\Anaconda3\lib\urllib\request.py in file_open(self, req)
#    1450                 raise URLError("file:// scheme is supported only on localhost")
#    1451         else:
# -> 1452             return self.open_local_file(req)
#    1453
#    1454     # names for the localhost
#
# ~\Anaconda3\lib\urllib\request.py in open_local_file(self, req)
#    1489                 return addinfourl(open(localfile, 'rb'), headers, origurl)
#    1490         except OSError as exp:
# -> 1491             raise URLError(exp)
#    1492         raise URLError('file not on local host')
#    1493
#
# URLError: <urlopen error [WinError 3] The system cannot find the path specified: 'C:\\Users\\Justin\\Documents\\Grad Courses\\DNSC 6211 - Programming for Analytics\\Week 11\\Web Scraping slides\\files\\third.html'>

# %%
# Slide 25
type(soup.li)
# Out:
# bs4.element.Tag

# %%
# Slide 25
tag = soup.li
tag.name
# Out:
# 'li'

# %%
# Slide 25
tag.attrs
# Out:
# {'class': ['util-item', 'util-item-left']}

# %%
# Slide 26
soup.head
# Out:
# <head>
# <meta charset="utf-8"/>
# <link href="https://www.gwu.edu/sites/all/themes/gwu_marketing/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <meta content="GW is making history through our academics, research, service, more than 275,000 prominent alumni and our 10 schools &amp; colleges. We offer comprehensive programs of undergraduate and graduate liberal arts study as well as degree programs in medicine, law, engineering, education, business, arts, international affairs, public affairs, nursing, public policy." name="description"/>
# <meta content="George washington university, gwu, gw, gw university, george washington, dc universities, dc colleges, education, higher education" name="keywords"/>
# <meta content="follow, index" name="robots"/>
# <meta content="Drupal 7 (http://drupal.org)" name="generator"/>
# <link href="http://www.gwu.edu/sites/www.gwu.edu/files/image/gw-primary_90x90.jpg" rel="image_src"/>
# <link href="https://www.gwu.edu/" rel="canonical"/>
# <link href="https://www.gwu.edu/" rel="shortlink"/>
# <style type="text/css">
# #header-wrapper .call-to-action {display:none;}
# .call-to-action {display:block;}
# }
# </style>
# <script src="https://siteimproveanalytics.com/js/siteanalyze_67741177.js"></script>
# <meta content="https://www.gwu.edu" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="The George Washington University | Washington, D.C." property="og:title"/>
# <meta content="No matter what subjects we pursue, we’ve all come here to change the course of history." property="og:description"/>
# <meta content="https://www.gwu.edu/sites/www.gwu.edu/files/The%20George%20Washington%20University.jpg" property="og:image"/>
# <title>The George Washington University</title>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width=device-width" name="viewport"/>
# <!--[if IEMobile]><meta http-equiv="cleartype" content="on"><![endif]-->
# <link href="https://www.gwu.edu/sites/www.gwu.edu/files/css/css_lQaZfjVpwP_oGNqdtWCSpJT1EMqXdMiU84ekLLxQnc4.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.gwu.edu/sites/www.gwu.edu/files/css/css_uJq4i_pXk1UmtbCovdeCsAhlfvrAFcmFexwn2c_hQDQ.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.gwu.edu/sites/www.gwu.edu/files/css/css_DJWZjqp7xy78aCfFyOruUdyBmtYwz9_mCBF7rI9N-tA.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.gwu.edu/sites/www.gwu.edu/files/css/css_Qa_cDfz3nVXqHYJr3OXqjyKWl1PJdUFyIClfY1HEFGg.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.gwu.edu/sites/www.gwu.edu/files/css/css_c50qa3Pyc7MiyD_giyM8QA-LE3CRd5353YAG4d5-HEc.css" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://www.gwu.edu/sites/www.gwu.edu/files/js/js_gPM6NXOQjN2XM2JWQGfy07nKmcdDFrL289YA7h80ySs.js"></script>
# <script src="https://www.gwu.edu/sites/www.gwu.edu/files/js/js_I_pQcXJFUoxtcQDfREZ7pvk97OmDPrMVd456aSzQuO4.js"></script>
# <script src="https://www.gwu.edu/sites/www.gwu.edu/files/js/js_XuFgHR1X67cDofve4crM47xw750TjafMBoVq4KMQLjo.js"></script>
# <script src="https://www.gwu.edu/sites/www.gwu.edu/files/js/js_FKPJDWMr4BilMHFnyyxc4Yov1-GG7QsgFJJK0IhH8aE.js"></script>
# <script src="https://www.gwu.edu/sites/all/modules/contrib/lightbox2/js/lightbox.js?1510261160"></script>
# <script src="https://www.gwu.edu/sites/www.gwu.edu/files/js/js_UfjTpqJUnqxJ6OUFeS-T1GgkrkM3kNhIEjkS-x9NGKg.js"></script>
# <script src="https://www.gwu.edu/sites/www.gwu.edu/files/js/js_NFp5R-TqOLzQVAx38R-zWtzhSXWaffM5FtZIAXxlKmM.js"></script>
# <script>jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"gwu_marketing","theme_token":"cxnyH7mwUfENYpYyIzMt7JcmAOyEjqPc2M2ofkGZtzs","jquery_version":"1.10","js":{"sites\/all\/modules\/custom\/gwu-anijs\/anijs\/anijs-min.js":1,"sites\/all\/modules\/custom\/gwu-anijs\/anijs\/helpers\/dom\/anijs-helper-dom-min.js":1,"sites\/all\/modules\/custom\/gwu_enliven\/snap.svg-min.js":1,"sites\/all\/modules\/custom\/gwu_enliven\/enlivenem.min.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/jquery\/1.10\/jquery.min.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.core.min.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.widget.min.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/external\/jquery.cookie.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/misc\/jquery.form.min.js":1,"sites\/all\/modules\/contrib\/nice_menus\/js\/jquery.bgiframe.js":1,"sites\/all\/modules\/contrib\/nice_menus\/js\/jquery.hoverIntent.js":1,"sites\/all\/modules\/contrib\/nice_menus\/js\/superfish.js":1,"sites\/all\/modules\/contrib\/nice_menus\/js\/nice_menus.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.tabs.min.js":1,"misc\/ajax.js":1,"sites\/all\/modules\/contrib\/jquery_update\/js\/jquery_update.js":1,"sites\/all\/modules\/custom\/gwustyle\/imagestyles.js":1,"misc\/progress.js":1,"sites\/all\/modules\/contrib\/fancybox\/fancybox.js":1,"sites\/all\/libraries\/fancybox\/source\/jquery.fancybox.pack.js":1,"sites\/all\/libraries\/fancybox\/lib\/jquery.mousewheel-3.0.6.pack.js":1,"sites\/all\/libraries\/fancybox\/source\/helpers\/jquery.fancybox-media.js":1,"sites\/all\/modules\/contrib\/lightbox2\/js\/lightbox.js":1,"sites\/all\/modules\/contrib\/views\/js\/base.js":1,"sites\/all\/modules\/contrib\/views\/js\/ajax_view.js":1,"sites\/all\/modules\/contrib\/quicktabs\/js\/quicktabs.js":1,"sites\/all\/modules\/contrib\/responsive_menus\/styles\/meanMenu\/jquery.meanmenu.min.js":1,"sites\/all\/modules\/contrib\/responsive_menus\/styles\/meanMenu\/responsive_menus_mean_menu.min.js":1,"sites\/all\/themes\/gwu_capital\/js\/script.js":1,"sites\/all\/themes\/gwu_capital\/js\/jquery.sticky.js":1,"sites\/all\/themes\/gwu_marketing\/js\/gwu.jquery.stickyNavbar.min.js":1,"sites\/all\/themes\/gwu_marketing\/js\/script.min.js":1,"sites\/all\/themes\/gwu_marketing\/js\/jquery-migrate-1.4.0.min.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"misc\/ui\/jquery.ui.core.css":1,"misc\/ui\/jquery.ui.theme.css":1,"misc\/ui\/jquery.ui.tabs.css":1,"sites\/all\/modules\/custom\/gwu-anijs\/anicollection.css":1,"sites\/all\/modules\/custom\/gwu_enliven\/enlivenem.css":1,"sites\/all\/modules\/contrib\/ldap\/ldap_user\/ldap_user.css":1,"modules\/aggregator\/aggregator.css":1,"sites\/all\/modules\/contrib\/date\/date_api\/date.css":1,"sites\/all\/modules\/contrib\/date\/date_popup\/themes\/datepicker.1.7.css":1,"sites\/all\/modules\/contrib\/date\/date_repeat_field\/date_repeat_field.css":1,"modules\/field\/theme\/field.css":1,"sites\/all\/modules\/contrib\/google_appliance\/theme\/google_appliance.css":1,"modules\/node\/node.css":1,"modules\/search\/search.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/contrib\/video_filter\/video_filter.css":1,"sites\/all\/modules\/contrib\/views\/css\/views.css":1,"sites\/all\/modules\/contrib\/ckeditor\/css\/ckeditor.css":1,"sites\/all\/modules\/custom\/gwustyle\/css\/admin.css":1,"sites\/all\/modules\/contrib\/ctools\/css\/ctools.css":1,"sites\/all\/libraries\/fancybox\/source\/jquery.fancybox.css":1,"sites\/all\/modules\/contrib\/ldap\/ldap_servers\/ldap_servers.admin.css":1,"sites\/all\/modules\/contrib\/lightbox2\/css\/lightbox.css":1,"sites\/all\/modules\/contrib\/panels\/css\/pan ...
# <!--[if lt IE 9]>
#     <script src="/sites/all/themes/zen/js/html5-respond.js"></script>
#     <![endif]-->
# <!--[if !IE 7]><style type="text/css">.ubberwrapper {display:table;height:100%}</style><![endif]-->
# </head>

# %%
# Slide 26
soup.head.title

#finds different parts of the html file for a certain website
# Out:
# <title>The George Washington University</title>

# %%
# Slide 26
soup.li.contents
# Out:
# [<a href="https://students.gwu.edu/?utm_source=utilitynav&amp;utm_medium=audience-students&amp;utm_campaign=gwhomepage-utility" target="_blank">Students</a>]

# %%
# Slide 27
soup.title
# Out:
# <title>The George Washington University</title>

# %%
# Slide 27
type(soup.title)
# Out:
# bs4.element.Tag

# %%
# Slide 27
soup.title.string
# Out:
# 'The George Washington University'

# %%
# Slide 27
type(soup.title.string)

# %%
# Slide 27
soup.title.string.parent

# %%
# Slide 27
str(soup.title.string)

# %%
# Slide 28
# Please explore slide 28 by inspecting it

# %%
# Slide 29
# Do in class

# %%
# Slide 30
import urllib.request
from bs4 import BeautifulSoup as bs

filename = "table.html"
url = "file:///"+path+filename
request = urllib.request.Request(url)
response = urllib.request.urlopen(request)
data = response.read()
response.close()

# Create the soup
soup = bs(data, "html.parser")

# ---- Now we start parsing the table

tables = soup.findAll('table')

for table in tables:
    rows = table.findAll('tr')
    for row in rows:
        cells = row.findAll('td')
        for cell in cells:
            print (cell.getText())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d5d01b25ddef> in <module>()
#       4
#       5 filename = "table.html"
# ----> 6 url = "file:///"+path+filename
#       7 request = urllib.request.Request(url)
#       8 response = urllib.request.urlopen(request)
#
# NameError: name 'path' is not defined

# %%
# Slide 31
import urllib.request
from bs4 import BeautifulSoup as bs

filename = "table.html"
url = "file:///"+path+filename
request = urllib.request.Request(url)
response = urllib.request.urlopen(request)
data = response.read()
response.close()

# Create the soup
soup = bs(data, "html.parser")

# ---- Now we start parsing the table


tables = soup.findAll('table')

myLists = []

for table in tables:
    rows = table.findAll('tr')
    # print "number of rows =", len(rows)
    r = []
    for row in rows:
        cells = row.findAll('td')
        # print "number of cols =", len(cells)
        c = []        
        for cell in cells:
            c.append(cell.getText())
        # print c
        r.append(c)
    myLists.append(r)

print (myLists)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\urllib\request.py in open_local_file(self, req)
#    1473         try:
# -> 1474             stats = os.stat(localfile)
#    1475             size = stats.st_size
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\Justin\\Documents\\Grad Courses\\DNSC 6211 - Programming for Analytics\\Week 11\\Web Scraping slides\\files\\table.html'
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-28-3f747d440ade> in <module>()
#       6 url = "file:///"+path+filename
#       7 request = urllib.request.Request(url)
# ----> 8 response = urllib.request.urlopen(request)
#       9 data = response.read()
#      10 response.close()
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\Anaconda3\lib\urllib\request.py in file_open(self, req)
#    1450                 raise URLError("file:// scheme is supported only on localhost")
#    1451         else:
# -> 1452             return self.open_local_file(req)
#    1453
#    1454     # names for the localhost
#
# ~\Anaconda3\lib\urllib\request.py in open_local_file(self, req)
#    1489                 return addinfourl(open(localfile, 'rb'), headers, origurl)
#    1490         except OSError as exp:
# -> 1491             raise URLError(exp)
#    1492         raise URLError('file not on local host')
#    1493
#
# URLError: <urlopen error [WinError 3] The system cannot find the path specified: 'C:\\Users\\Justin\\Documents\\Grad Courses\\DNSC 6211 - Programming for Analytics\\Week 11\\Web Scraping slides\\files\\table.html'>

# %%
# Slide 31
# This part shows how you get Pandas dataframes from lists

import pandas as pd

headings = ['Heading1', 'Heading2','Heading3']

df1 = pd.DataFrame(myLists[0], columns=headings)
df2 = pd.DataFrame(myLists[1], columns=headings)

print(df1)

print(df2)

# %%
# Slide 32
from bs4 import BeautifulSoup as bs
import requests

url="http://www.usatoday.com/sports/nfl/rankings/"
r = requests.get(url)
data = r.text    
soup = bs(data, "html.parser")

rows = soup.find("table").find("tbody").find_all("tr")
print(rows)

teams = soup.findAll('table',{'class':'ribbonfx rankings no-autorank'})
print("length of teams", len(teams))

for team in teams:
    rows = team.findAll('tr')
    for row in rows:
        teamRank = row.find('td',{'class':'ranking'})
        teamSlug = row.findAll('td',{'class':'team_slug'})
        teamRcrd = row.findAll('td',{'class':'record'})
        teamDiff = row.findAll('td',{'class':'ranking diff'})
        teamHilo = row.findAll('td',{'class':'ranking hilo'})
        teamNote = row.findAll('td',{'class':'notes'})
        print(type(teamRank), " ", teamRank)
# Out:
# [<tr><td class="ranking">
#
#                                     1
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/eagles/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/PHI.png"/></span></span><span class="first_name">Philadelphia</span><br/><span class="last_name">Eagles</span></a></td><td class="record">
#
#                                     8-1
#
#                             </td><td class="ranking_diff"><span class="rank-sm-no"></span></td><td class="ranking_hilo">
#
#                                     1 / 24
#
#                             </td><td class="notes">
#
#                                     Already 3-0 in NFC East, Philly can put virtual lock on division crown - and put another nail in Cowboys' coffin - by winning at Dallas Sunday.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     2
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/patriots/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/NE.png"/></span></span><span class="first_name">New England</span><br/><span class="last_name">Patriots</span></a></td><td class="record">
#
#                                     7-2
#
#                             </td><td class="ranking_diff"><span class="rank-sm-up">1</span></td><td class="ranking_hilo">
#
#                                     1 / 12
#
#                             </td><td class="notes">
#
#                                     Talk about a TOTAL team effort. Everyone on New England's game-day roster played Sunday night, and even new backup QB Brian Hoyer looked good.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     3
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/steelers/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/PIT.png"/></span></span><span class="first_name">Pittsburgh</span><br/><span class="last_name">Steelers</span></a></td><td class="record">
#
#                                     7-2
#
#                             </td><td class="ranking_diff"><span class="rank-sm-dn">1</span></td><td class="ranking_hilo">
#
#                                     2 / 14
#
#                             </td><td class="notes">
#
#                                     If they continue to play to their level of competition rest of the way, Pittsburgh fans will be witness to a lot of very bad football.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     4
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/rams/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/LA.png"/></span></span><span class="first_name">Los Angeles</span><br/><span class="last_name">Rams</span></a></td><td class="record">
#
#                                     7-2
#
#                             </td><td class="ranking_diff"><span class="rank-sm-no"></span></td><td class="ranking_hilo">
#
#                                     4 / 28
#
#                             </td><td class="notes">
#
#                                     Raise your hand if you thought Robert Woods would be the most impactful former Buffalo receiver GM Les Snead acquired before this season.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     5
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/saints/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/NO.png"/></span></span><span class="first_name">New Orleans</span><br/><span class="last_name">Saints</span></a></td><td class="record">
#
#                                     7-2
#
#                             </td><td class="ranking_diff"><span class="rank-sm-no"></span></td><td class="ranking_hilo">
#
#                                     5 / 26
#
#                             </td><td class="notes">
#
#                                     Mark Ingram, Alvin Kamara only needed Adrian Peterson to leave to become NFL's best RB duo. They've combined for 1,129 yards, 11 TDs since Week 6.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     6
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/panthers/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/CAR.png"/></span></span><span class="first_name">Carolina</span><br/><span class="last_name">Panthers</span></a></td><td class="record">
#
#                                     7-3
#
#                             </td><td class="ranking_diff"><span class="rank-sm-no"></span></td><td class="ranking_hilo">
#
#                                     2 / 20
#
#                             </td><td class="notes">
#
#                                     Suffocating defense. Cam Newton running and passing ball all over the yard. Awakening ground attack. Carolina looking a lot like 2015's NFC champs.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     7
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/chiefs/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/KC.png"/></span></span><span class="first_name">Kansas City</span><br/><span class="last_name">Chiefs</span></a></td><td class="record">
#
#                                     6-3
#
#                             </td><td class="ranking_diff"><span class="rank-sm-up">1</span></td><td class="ranking_hilo">
#
#                                     1 / 9
#
#                             </td><td class="notes">
#
#                                     They needed a week off to recharge. But bye didn't pass without incident after DL Roy Miller earned pink slip for allegedly assaulting his wife.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     8
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/vikings/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/MIN.png"/></span></span><span class="first_name">Minnesota</span><br/><span class="last_name">Vikings</span></a></td><td class="record">
#
#                                     7-2
#
#                             </td><td class="ranking_diff"><span class="rank-sm-up">4</span></td><td class="ranking_hilo">
#
#                                     7 / 19
#
#                             </td><td class="notes">
#
#                                     In a season with so much league-wide adversity, the return of QB Teddy Bridgewater is easily one of the most uplifting stories of the year.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     9
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/jaguars/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/JAC.png"/></span></span><span class="first_name">Jacksonville</span><br/><span class="last_name">Jaguars</span></a></td><td class="record">
#
#                                     6-3
#
#                             </td><td class="ranking_diff"><span class="rank-sm-no"></span></td><td class="ranking_hilo">
#
#                                     9 / 26
#
#                             </td><td class="notes">
#
#                                     Just when Blake Bortles was making case to stay beyond this season, it became apparent anew that Jacksonville will be hot QB destination in 2018.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     10
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/titans/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/TEN.png"/></span></span><span class="first_name">Tennessee</span><br/><span class="last_name">Titans</span></a></td><td class="record">
#
#                                     6-3
#
#                             </td><td class="ranking_diff"><span class="rank-sm-up">5</span></td><td class="ranking_hilo">
#
#                                     7 / 23
#
#                             </td><td class="notes">
#
#                                     RB DeMarco Murray declared, 'I know we're better when I'm out there' last week. Then he scored all three of Tennessee's TDs Sunday.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     11
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/seahawks/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/SEA.png"/></span></span><span class="first_name">Seattle</span><br/><span class="last_name">Seahawks</span></a></td><td class="record">
#
#                                     6-3
#
#                             </td><td class="ranking_diff"><span class="rank-sm-no"></span></td><td class="ranking_hilo">
#
#                                     3 / 15
#
#                             </td><td class="notes">
#
#                                     Remember offseason trade talk around Richard Sherman? 'Hawks about to learn how important their stud corner is as he misses first games of career.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     12
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/falcons/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/ATL.png"/></span></span><span class="first_name">Atlanta</span><br/><span class="last_name">Falcons</span></a></td><td class="record">
#
#                                     5-4
#
#                             </td><td class="ranking_diff"><span class="rank-sm-up">2</span></td><td class="ranking_hilo">
#
#                                     2 / 14
#
#                             </td><td class="notes">
#
#                                     Only natural to wonder how Super Bowl LI might have turned out had DE Adrian Clayborn not torn his biceps in last season's divisional round.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     13
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/lions/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/DET.png"/></span></span><span class="first_name">Detroit</span><br/><span class="last_name">Lions</span></a></td><td class="record">
#
#                                     5-4
#
#                             </td><td class="ranking_diff"><span class="rank-sm-up">3</span></td><td class="ranking_hilo">
#
#                                     2 / 23
#
#                             </td><td class="notes">
#
#                                     LT Taylor Decker's return to lineup Sunday could quietly be one of the key personnel upgrades across the league during second half.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     14
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/cowboys/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/DAL.png"/></span></span><span class="first_name">Dallas</span><br/><span class="last_name">Cowboys</span></a></td><td class="record">
#
#                                     5-4
#
#                             </td><td class="ranking_diff"><span class="rank-sm-dn">7</span></td><td class="ranking_hilo">
#
#                                     5 / 19
#
#                             </td><td class="notes">
#
#                                     Turns out LT Tyron Smith is actually Dallas' MVP ... unless it's really LB Sean Lee. Can't afford either one to take an international vacation.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     15
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/redskins/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/WAS.png"/></span></span><span class="first_name">Washington</span><br/><span class="last_name">Redskins</span></a></td><td class="record">
#
#                                     4-5
#
#                             </td><td class="ranking_diff"><span class="rank-sm-dn">5</span></td><td class="ranking_hilo">
#
#                                     6 / 25
#
#                             </td><td class="notes">
#
#                                     Kirk Cousins tied for club lead with three rush TDs. Nice point for contract negotiations ... and better indication of where this team struggles.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     16
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/bills/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/BUF.png"/></span></span><span class="first_name">Buffalo</span><br/><span class="last_name">Bills</span></a></td><td class="record">
#
#                                     5-4
#
#                             </td><td class="ranking_diff"><span class="rank-sm-dn">3</span></td><td class="ranking_hilo">
#
#                                     3 / 28
#
#                             </td><td class="notes">
#
#                                     Sean McDermott knows New Era Field has a turf surface, right? Maybe that's why Buffalo couldn't find any dirt to defend Sunday afternoon.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     17
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/raiders/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/OAK.png"/></span></span><span class="first_name">Oakland</span><br/><span class="last_name">Raiders</span></a></td><td class="record">
#
#                                     4-5
#
#                             </td><td class="ranking_diff"><span class="rank-sm-up">1</span></td><td class="ranking_hilo">
#
#                                     3 / 22
#
#                             </td><td class="notes">
#
#                                     They emerge from bye week with three consecutive "home" games, beginning Sunday afternoon in ... Mexico City with near must-win against Pats.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     18
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/ravens/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/BAL.png"/></span></span><span class="first_name">Baltimore</span><br/><span class="last_name">Ravens</span></a></td><td class="record">
#
#                                     4-5
#
#                             </td><td class="ranking_diff"><span class="rank-sm-up">4</span></td><td class="ranking_hilo">
#
#                                     11 / 28
#
#                             </td><td class="notes">
#
#                                     Not a bad bye. QB Joe Flacco got more rest, and RB Danny Woodhead is nearing return from IR. Meanwhile, several AFC wild-card competitors faltered.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     19
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/packers/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/GB.png"/></span></span><span class="first_name">Green Bay</span><br/><span class="last_name">Packers</span></a></td><td class="record">
#
#                                     5-4
#
#                             </td><td class="ranking_diff"><span class="rank-sm-up">7</span></td><td class="ranking_hilo">
#
#                                     2 / 26
#
#                             </td><td class="notes">
#
#                                     We thought Mike McCarthy could have done better than Brett Hundley. We must now admit steadily improving QB might just keep Pack on life support.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     20
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/jets/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/NYJ.png"/></span></span><span class="first_name">New York</span><br/><span class="last_name">Jets</span></a></td><td class="record">
#
#                                     4-6
#
#                             </td><td class="ranking_diff"><span class="rank-sm-up">1</span></td><td class="ranking_hilo">
#
#                                     20 / 32
#
#                             </td><td class="notes">
#
#                                     Just when it seemed appropriate to drink the green Kool-Aid, NYJ reminded us they're not a very good team ... and may not win another game.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     21
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/dolphins/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/MIA.png"/></span></span><span class="first_name">Miami</span><br/><span class="last_name">Dolphins</span></a></td><td class="record">
#
#                                     4-5
#
#                             </td><td class="ranking_diff"><span class="rank-sm-up">2</span></td><td class="ranking_hilo">
#
#                                     11 / 30
#
#                             </td><td class="notes">
#
#                                     Torture defined - watching this team in prime time three weeks in a row. At least Kenyan Drake finally notched Miami's first rushing TD of 2017.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     22
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/chargers/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/LAC.png"/></span></span><span class="first_name">Los Angeles</span><br/><span class="last_name">Chargers</span></a></td><td class="record">
#
#                                     3-6
#
#                             </td><td class="ranking_diff"><span class="rank-sm-dn">5</span></td><td class="ranking_hilo">
#
#                                     13 / 31
#
#                             </td><td class="notes">
#
#                                     S Tre Boston picked off TWO passes in final two minutes of regulation Sunday as Bolts tried to salt away three-point lead. "Tre" needed three.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     23
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/cardinals/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/ARI.png"/></span></span><span class="first_name">Arizona</span><br/><span class="last_name">Cardinals</span></a></td><td class="record">
#
#                                     4-5
#
#                             </td><td class="ranking_diff"><span class="rank-sm-up">1</span></td><td class="ranking_hilo">
#
#                                     11 / 28
#
#                             </td><td class="notes">
#
#                                     Woody Hayes would have loved Arizona's new Adrian Peterson-centric offense - 3.6 yards and a cloud of desert dust.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     24
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/bengals/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/CIN.png"/></span></span><span class="first_name">Cincinnati</span><br/><span class="last_name">Bengals</span></a></td><td class="record">
#
#                                     3-6
#
#                             </td><td class="ranking_diff"><span class="rank-sm-up">1</span></td><td class="ranking_hilo">
#
#                                     21 / 31
#
#                             </td><td class="notes">
#
#                                     The defense was stuck on field for more than 40 minutes Sunday. Can you really blame Vontaze Burfict for wanting to hit showers early?
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     25
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/broncos/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/DEN.png"/></span></span><span class="first_name">Denver</span><br/><span class="last_name">Broncos</span></a></td><td class="record">
#
#                                     3-6
#
#                             </td><td class="ranking_diff"><span class="rank-sm-dn">5</span></td><td class="ranking_hilo">
#
#                                     4 / 25
#
#                             </td><td class="notes">
#
#                                     Just when you thought Denver had hit rock bottom, the special teams suffer a near-complete breakdown to extend losing skid to five games.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     26
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/buccaneers/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/TB.png"/></span></span><span class="first_name">Tampa Bay</span><br/><span class="last_name">Buccaneers</span></a></td><td class="record">
#
#                                     3-6
#
#                             </td><td class="ranking_diff"><span class="rank-sm-up">2</span></td><td class="ranking_hilo">
#
#                                     8 / 28
#
#                             </td><td class="notes">
#
#                                     Defense picked good time to have its best game, nearly doubling season sack total, with Jameis Winston and Mike Evans in street clothes.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     27
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/bears/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/CHI.png"/></span></span><span class="first_name">Chicago</span><br/><span class="last_name">Bears</span></a></td><td class="record">
#
#                                     3-6
#
#                             </td><td class="ranking_diff"><span class="rank-sm-dn">8</span></td><td class="ranking_hilo">
#
#                                     19 / 30
#
#                             </td><td class="notes">
#
#                                     John Fox's decision to challenge RB Benny Cunningham's not-really-a-touchdown right at top of the list of worst game management moves of 2017.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     28
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/colts/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/IND.png"/></span></span><span class="first_name">Indianapolis</span><br/><span class="last_name">Colts</span></a></td><td class="record">
#
#                                     3-7
#
#                             </td><td class="ranking_diff"><span class="rank-sm-up">1</span></td><td class="ranking_hilo">
#
#                                     23 / 30
#
#                             </td><td class="notes">
#
#                                     Would Vontae Davis' presence on a defense giving up more points than any in the league have been enough to complete an upset of the Steelers?
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     29
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/texans/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/HOU.png"/></span></span><span class="first_name">Houston</span><br/><span class="last_name">Texans</span></a></td><td class="record">
#
#                                     3-6
#
#                             </td><td class="ranking_diff"><span class="rank-sm-dn">2</span></td><td class="ranking_hilo">
#
#                                     11 / 29
#
#                             </td><td class="notes">
#
#                                     Tom Savage has seven turnovers in three starts after four more miscues Sunday. How long will Bill O'Brien keep pretending he's best option?
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     30
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/49ers/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/SF.png"/></span></span><span class="first_name">San Francisco</span><br/><span class="last_name">49ers</span></a></td><td class="record">
#
#                                     1-9
#
#                             </td><td class="ranking_diff"><span class="rank-sm-up">1</span></td><td class="ranking_hilo">
#
#                                     24 / 31
#
#                             </td><td class="notes">
#
#                                     Courageous performance by WR Marquise Goodwin hours after tragic death of his son. Niners will win a lot more games building with guys like him.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     31
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/giants/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/NYG.png"/></span></span><span class="first_name">New York</span><br/><span class="last_name">Giants</span></a></td><td class="record">
#
#                                     1-8
#
#                             </td><td class="ranking_diff"><span class="rank-sm-dn">1</span></td><td class="ranking_hilo">
#
#                                     10 / 31
#
#                             </td><td class="notes">
#
#                                     Based on his effort Sunday, CB Janoris Jenkins still thought he was on suspension or else is just trying to get coach Ben McAdoo fired.
#
#                             </td></tr>, <tr><td class="ranking">
#
#                                     32
#
#                             </td><td class="team_slug"><a class="sp-head-team-link" href="/sports/nfl/browns/"><span class="logo"><span class="logo-s"><img src="https://www.gannett-cdn.com/media/SMG/sports_logos/nfl-whitebg/30/CLE.png"/></span></span><span class="first_name">Cleveland</span><br/><span class="last_name">Browns</span></a></td><td class="record">
#
#                                     0-9
#
#                             </td><td class="ranking_diff"><span class="rank-sm-no"></span></td><td class="ranking_hilo">
#
#                                     27 / 32
#
#                             </td><td class="notes">
#
#                                     Cleveland's ownership, executives and coaches have made so many poor decisions over the years, why shouldn't DeShone Kizer get to make one, too?
#
#                             </td></tr>]
# length of teams 1
# <class 'NoneType'>   None
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     1
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     2
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     3
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     4
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     5
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     6
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     7
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     8
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     9
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     10
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     11
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     12
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     13
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     14
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     15
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     16
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     17
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     18
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     19
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     20
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     21
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     22
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     23
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     24
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     25
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     26
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     27
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     28
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     29
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     30
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     31
#
#                             </td>
# <class 'bs4.element.Tag'>   <td class="ranking">
#
#                                     32
#
#                             </td>

# %%
# Slide 32
from bs4 import BeautifulSoup as bs
import requests

url="http://www.usatoday.com/sports/nfl/rankings/"
r = requests.get(url)
data = r.text    
soup = bs(data, "html.parser")

rows = soup.find("table").find("tbody").findAll("tr")

for row in rows:
    teamRank = row.find('td',{'class':'ranking'})
    teamSlug = row.findAll('td',{'class':'team_slug'})
    teamRcrd = row.findAll('td',{'class':'record'})
    teamDiff = row.findAll('td',{'class':'ranking diff'})
    teamHilo = row.findAll('td',{'class':'ranking hilo'})
    teamNote = row.find('td',{'class':'notes'})
    print(type(teamRank))
    #print(teamRank.getText(), " ------->>   ", str(teamNote))
# Out:
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
