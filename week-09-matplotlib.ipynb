# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0, 10)
y = np.random.rand(10)
plt.plot(x,y)
plt.show()

# %%
# Slide 8
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 2, 100)
plt.plot(x, x, label='linear')
plt.show()

# %%
x = np.linspace(0, 2, 100)
plt.plot(x, x)
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.show()

# %%
x = np.linspace(0, 2, 100)
plt.plot(x, x**2)
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.show()

# %%
x = np.linspace(0, 2, 100)
plt.plot(x, x**3)
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.show()

# %%
# Slide 8
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 2, 100)
plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()
plt.show()

# %%
# Slide 11
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, color='g', alpha=.75)
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
y = matplotlib.mlab.normpdf(bins, mu, sigma)
plt.plot(bins, y, 'k--', linewidth=3.5, color='orange')
plt.annotate('theoretical dist', xy=(110, .020), xytext=(130, .025),
arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.show()

# %%
# Slide 12
from scipy import stats
import seaborn as sns  # sudo pip install seaborn
#plt.ioff()
#plt.cla()
x = stats.gamma(3).rvs(5000)
y = stats.gamma(5).rvs(5000)
y = stats.norm(0,1).rvs(5000)
with sns.axes_style("white"):
    sns.jointplot(x, y, kind="hex")
plt.show()

# %%
# Slide 12
import matplotlib.pyplot as plt
#plt.clf()
#plt.cla()
from scipy import stats
import seaborn as sns
x = stats.gamma(5).rvs(10000)
y = stats.gamma(5).rvs(10000)
with sns.axes_style("white"):
    sns.jointplot(x, y, kind="kde")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(2,2)

# The animation part (not working for some reason)
import matplotlib.animation as animation
x = np.arange(0, 2*np.pi, 0.01) # x-array
line, = ax[0,0].plot(x, np.sin(x))

def animate(i):
    line.set_ydata(np.sin(x+i/10.0)) # update the data
    return line,

#Init only required for blitting to give a clean slate.
def init():
    line.set_ydata(np.ma.array(x, mask=True))
    return line,

#ani = animation.FuncAnimation(fig, animate, np.arange(1, 200), init_func=init, interval=25, blit=True)

# http://matplotlib.org/1.3.1/users/image_tutorial.html
import matplotlib.image as mpimg
img=mpimg.imread('/home/drk/kanungo/DNSC6211/week09/Code and notebooks/matplotlib/apple.jpg')
ax[1,1].imshow(img)
ax[1,1].axis('off')

x1 = np.arange(1,9)
y1 = [30, 40, 20, 50, 60, 80, 50, 70]

# http://matplotlib.org/examples/api/barchart_demo.html
barwidth = 0.5
ax[0,1].bar(x1, y1, barwidth, color='aquamarine', edgecolor='black', hatch="/")

from scipy.interpolate import spline
#from scipy.interpolate import Bspline
xnew = np.linspace(x1.min(), x1.max(), 300)
y_smooth = spline(x1, y1, xnew)

ax[1,0].plot(xnew, y_smooth, color='orange', linewidth=2)
ax[1,0].plot(x1, y1, 'ro',
markersize=8,
markerfacecolor='black',
markeredgewidth=1,
markeredgecolor='lightblue')

plt.show()
